# %% [markdown]
# # Bookworm
#
#
# ## Overview
#
# In this project, you will build a simple question-answering agent that is able to learn from any text data you provide, and answer queries posed in natural language. You will use IBM Watson's cloud-based services to process the input text data and find relevant responses.
#
# ## Learning Objectives
#
# By completing this project, you will learn how to:
#
# - Create a cloud-based NLP service instance and configure it.
# - Ingest a set of text documents using the service and analyze the results.
# - Accept questions in natural language and parse them.
# - Find relevant answers from the preprocessed text data.
#
# ## Getting Started
#
# In order to use Watson's cloud-based services, you first need to create an account on the [IBM Bluemix platform](https://console.ng.bluemix.net/).
#
# <div>
#     <div style="display: table-cell; width: 50%;">
#         <img src="images/watson-logo.png" alt="IBM Watson logo" width="200" />
#     </div>
#     <div style="display: table-cell; width: 50%;">
#         <img src="images/bluemix-logo.png" alt="IBM Bluemix logo" width="400" />
#     </div>
# </div>
#
# Then, for each service you want to use, you have to create an instance of that service. You can continue with the tasks below, and create a service instance when indicated.

# %% [markdown]
# ## 1. Create and configure Discovery service
#
# Create an instance of the **Discovery** service. You will use this to process a set of text documents, and _discover_ relevant facts and relationships.
#
# - Go to the [IBM Bluemix Catalog](https://console.ng.bluemix.net/catalog/?taxonomyNavigation=services&category=watson).
# - Select the service you want, **Discovery**, under the **Watson** category.
# - Enter a Service Name for that instance, e.g. **Disco1** and a Credential Name, e.g. **Disco1-Creds** (these are just for you to be able to refer to later, they do not affect the functioning of the service).
# - You should be able to see your newly-created service in your [Services Dashboard](https://console.ng.bluemix.net/dashboard/services).
# - Open the service instance, click on the **Service credentials** tab, and then **View credentials** under Actions. This is where you will find the username and password to use when connecting to the service.
#
# <img src="images/discovery-creds.png" alt="Discovery Service - Credentials tab" width="800" />
#
# Save the credentials for the discovery service in a JSON file in the current directory named `service-credentials.json` with the following format:
#
# ```json
# {
#     "discovery": {
#         "username": "<your Discovery username here>",
#         "password": "<your Discovery password here>"
#     },
#     "conversation": {
#         "username": "",
#         "password": ""
#     }
# }
#
# ```
#
# You will be filling out the Conversation service credentials later, when you create an instance for it. Note that you should keep these credentials secret. Please do not turn them in with your submission!
#
# ### Connect to the service instance
#
# Let's connect to the service instance you just created using IBM Watson's [Python SDK](https://github.com/watson-developer-cloud/python-sdk). You will first need to install the SDK:
# ```bash
# pip install watson-developer-cloud
# ```
#
# Now execute each code cell below using **`Shift+Enter`**, and complete any steps indicated by a **`TODO`** comment. For more information on the Discovery service, please read the [Documentation](https://www.ibm.com/watson/developercloud/doc/discovery/index.html) and look at the [API Reference](https://www.ibm.com/watson/developercloud/discovery/api/v1/?python) as needed.

# %%
# Usual Python imports
import sys
import os
import glob
import json

# BeautifulSoup, for parsing HTML
from bs4 import BeautifulSoup

# Matplotlib, for plotting
import matplotlib.pyplot as plt
# %matplotlib inline

# Watson Python SDK
import watson_developer_cloud

# Utility functions
import helper

# %%
# Connect to the Discovery service instance
# TODO: Ensure that your username and password from the Service Credentials tab are in service-credentials.json
# Note that these credentials are different from your IBM Bluemix login, and are specific to the service instance
discovery_creds = helper.fetch_credentials('discovery')
discovery = watson_developer_cloud.DiscoveryV1(
    version='2017-07-11',
    username=discovery_creds['username'],
    password=discovery_creds['password'])

# %% [markdown]
# ### Create an environment
#
# The Discovery service organizes everything needed for a particular application in an _environment_. Let's create one called "Bookworm" for this project.
#
# > _**Note**: It is okay to run this block multiple times - it will not create duplicate environments with the same name._

# %%
# Prepare an environment to work in
env, env_id = helper.fetch_object(
    discovery, "environment", "Bookworm",
    create=True, create_args=dict(
        description="A space to read and understand stories",  # feel free to edit
        size=0  # use 0 for free plan (see API reference for more on sizing)
    ))
print(json.dumps(env, indent=2))
# Out:
# Found environment: Bookworm (4ac0532a-a59f-4d11-8eae-8eb9d6b3db6f)
# {
#   "updated": "2018-08-07T17:47:29.756Z",
#   "created": "2018-08-07T17:47:29.756Z",
#   "read_only": false,
#   "index_capacity": {
#     "disk_usage": {
#       "total_bytes": 200000000,
#       "used": "20.435 KB",
#       "percent_used": 0.01,
#       "total": "200 MB",
#       "used_bytes": 20435
#     },
#     "memory_usage": {
#       "total_bytes": -1,
#       "used": "N/A",
#       "percent_used": -1.0,
#       "total": "N/A",
#       "used_bytes": -1
#     },
#     "documents": {
#       "maximum_allowed": 1000,
#       "available": 1
#     }
#   },
#   "status": "active",
#   "environment_id": "4ac0532a-a59f-4d11-8eae-8eb9d6b3db6f",
#   "name": "Bookworm",
#   "description": "A space to read and understand stories",
#   "size": -1
# }

# %% [markdown]
# ### Verify configuration options
#
# A _configuration_ defines what natural language processing routines are applied to any documents that are submitted to the service. Each environment gets a default configuration when it is created.
#
# You can fetch the default configuration and view the different options using the following piece of code.

# %%
conf_dict = discovery.list_configurations(environment_id=env_id)

# %%
# View default configuration
cfg_id = '0fa6ce41-4d8d-4d06-be9b-571991f5140b'
cfg = discovery.get_configuration(environment_id=env_id, configuration_id=cfg_id)

# %% [markdown]
# There are 3 main configuration blocks that affect how input documents are processed:
#
# 1. **`conversions`**: How to convert documents in various formats (Word, PDF, HTML) and extract elements that indicate some structure (e.g. headings).
# 2. **`enrichments`**: What NLP output results are we interested in (keywords, entities, sentiment, etc.).
# 3. **`normalizations`**: Post-processing steps to be applied to the output. This can be left empty in most cases, unless you need the output to be normalized into a very specific format.
#
# _**Note**: The default configuration for an environment cannot be modified. If you need to change any of the options, you will need to create a new one, and then edit it. The easiest way to do this is using the service dashboard, which is described later._

# %% [markdown]
# ### Test your configuration
#
# It is a good idea to test your configuration on a small sample text before you apply it to a larger document collection.
#
# _**Note**: We have supplied a sample document (`data/sample.html`) containing the opening crawl text for Star Wars: Episode IV, but you are free to use a text of your choosing._
#
# **Q**: (optional) If you use your own sample text, provide a brief title and description below.
#
# **A**:

# %%
print(discovery)
# Out:
# <watson_developer_cloud.discovery_v1.DiscoveryV1 object at 0x1125e4d30>

# %%
# Test configuration on some sample text
data_dir = "data"
filename = os.path.join(data_dir, "sample.html")
with open(filename, "r") as f:
    with open ("cfg.json", "r") as cfgf:
        res = discovery.test_configuration_in_environment(environment_id=env_id, configuration_id=cfg_id, file=f)
print(json.dumps(res, indent=2))
# Out:
# {
#   "original_media_type": "text/html",
#   "notices": [
#     {
#       "severity": "warning",
#       "step": "enrichments",
#       "description": "relations: cannot analyze: downstream issue",
#       "notice_id": "downstream_service - enriched_text"
#     }
#   ],
#   "status": "completed",
#   "snapshots": [
#     {
#       "step": "html_input",
#       "snapshot": {
#         "html": "<html>\n<head>\n    <title>Star Wars: Episode IV - A New Hope (Opening Crawl)</title>\n</head>\n<body>\n    <article>\n        <h1>Star Wars: Episode IV - A New Hope (Opening Crawl)</h1>\n        <p>\n            It is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n        </p><p>\n            During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n        </p><p>\n            Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...\n        </p>\n    </article>\n</body>"
#       }
#     },
#     {
#       "step": "html_output",
#       "snapshot": {
#         "html": "<?xml version='1.0' encoding='UTF-8' standalone='yes'?><html>\n<head>\n    <meta content=\"text/html; charset=UTF-8\" http-equiv=\"Content-Type\"/>\n    <title>Star Wars: Episode IV - A New Hope (Opening Crawl)</title>\n\n</head>\n<body>\n\n    <article>\n        <h1>Star Wars: Episode IV - A New Hope (Opening Crawl)</h1>\n        <p>\n            It is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n        </p><p>\n            During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n        </p><p>\n            Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...\n        </p>\n    </article>\n</body></html>"
#       }
#     },
#     {
#       "step": "json_output",
#       "snapshot": {
#         "html": "<?xml version='1.0' encoding='UTF-8' standalone='yes'?><html>\n<head>\n    <meta content=\"text/html; charset=UTF-8\" http-equiv=\"Content-Type\"/>\n    \n    <title>Star Wars: Episode IV - A New Hope (Opening Crawl)</title>\n\n\n</head>\n<body>\n\n\n    <article>\n        <h1>Star Wars: Episode IV - A New Hope (Opening Crawl)</h1>\n        <p>\n            It is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n        </p><p>\n            During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n        </p><p>\n            Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...\n        </p>\n    </article>\n</body></html>",
#         "text": "Star Wars: Episode IV - A New Hope (Opening Crawl)\n\nStar Wars: Episode IV - A New Hope (Opening Crawl)\n\nIt is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n\nDuring the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n\nPursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#         "extracted_metadata": {
#           "title": "Star Wars: Episode IV - A New Hope (Opening Crawl)"
#         }
#       }
#     },
#     {
#       "step": "json_normalizations_output",
#       "snapshot": {
#         "html": "<?xml version='1.0' encoding='UTF-8' standalone='yes'?><html>\n<head>\n    <meta content=\"text/html; charset=UTF-8\" http-equiv=\"Content-Type\"/>\n    \n    <title>Star Wars: Episode IV - A New Hope (Opening Crawl)</title>\n\n\n</head>\n<body>\n\n\n    <article>\n        <h1>Star Wars: Episode IV - A New Hope (Opening Crawl)</h1>\n        <p>\n            It is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n        </p><p>\n            During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n        </p><p>\n            Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...\n        </p>\n    </article>\n</body></html>",
#         "text": "Star Wars: Episode IV - A New Hope (Opening Crawl)\n\nStar Wars: Episode IV - A New Hope (Opening Crawl)\n\nIt is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n\nDuring the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n\nPursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#         "extracted_metadata": {
#           "title": "Star Wars: Episode IV - A New Hope (Opening Crawl)"
#         }
#       }
#     },
#     {
#       "step": "enrichments_output",
#       "snapshot": {
#         "enriched_text": {
#           "entities": [],
#           "categories": [
#             {
#               "label": "/art and entertainment/movies and tv/movies",
#               "score": 0.584247
#             },
#             {
#               "label": "/society/unrest and war",
#               "score": 0.517031
#             },
#             {
#               "label": "/law, govt and politics/armed forces/army",
#               "score": 0.215561
#             }
#           ],
#           "sentiment": {
#             "document": {
#               "label": "negative",
#               "score": -0.575489
#             }
#           },
#           "concepts": [
#             {
#               "relevance": 0.98887,
#               "text": "Star Wars Episode IV: A New Hope",
#               "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_IV:_A_New_Hope"
#             },
#             {
#               "relevance": 0.985705,
#               "text": "Star Wars",
#               "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars"
#             },
#             {
#               "relevance": 0.90639,
#               "text": "Rebel Alliance",
#               "dbpedia_resource": "http://dbpedia.org/resource/Rebel_Alliance"
#             },
#             {
#               "relevance": 0.805771,
#               "text": "Luke Skywalker",
#               "dbpedia_resource": "http://dbpedia.org/resource/Luke_Skywalker"
#             },
#             {
#               "relevance": 0.801062,
#               "text": "Star Wars Episode V: The Empire Strikes Back",
#               "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_V:_The_Empire_Strikes_Back"
#             },
#             {
#               "relevance": 0.777337,
#               "text": "Darth Vader",
#               "dbpedia_resource": "http://dbpedia.org/resource/Darth_Vader"
#             },
#             {
#               "relevance": 0.77159,
#               "text": "Star Wars Episode VI: Return of the Jedi",
#               "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_VI:_Return_of_the_Jedi"
#             },
#             {
#               "relevance": 0.748553,
#               "text": "Grand Moff Tarkin",
#               "dbpedia_resource": "http://dbpedia.org/resource/Grand_Moff_Tarkin"
#             }
#           ],
#           "keywords": [
#             {
#               "relevance": 0.920159,
#               "text": "Opening Crawl"
#             },
#             {
#               "relevance": 0.785031,
#               "text": "New Hope"
#             },
#             {
#               "relevance": 0.775799,
#               "text": "Princess Leia races"
#             },
#             {
#               "relevance": 0.771384,
#               "text": "Star Wars"
#             },
#             {
#               "relevance": 0.767527,
#               "text": "evil Galactic Empire"
#             },
#             {
#               "relevance": 0.747615,
#               "text": "armored space station"
#             },
#             {
#               "relevance": 0.669776,
#               "text": "Rebel spaceships"
#             },
#             {
#               "relevance": 0.656828,
#               "text": "Rebel spies"
#             },
#             {
#               "relevance": 0.609404,
#               "text": "sinister agents"
#             },
#             {
#               "relevance": 0.600682,
#               "text": "civil war"
#             },
#             {
#               "relevance": 0.597836,
#               "text": "hidden base"
#             },
#             {
#               "relevance": 0.594694,
#               "text": "ultimate weapon"
#             },
#             {
#               "relevance": 0.582765,
#               "text": "secret plans"
#             },
#             {
#               "relevance": 0.582596,
#               "text": "entire planet"
#             },
#             {
#               "relevance": 0.574413,
#               "text": "DEATH STAR"
#             },
#             {
#               "relevance": 0.465394,
#               "text": "custodian"
#             },
#             {
#               "relevance": 0.462247,
#               "text": "Episode"
#             },
#             {
#               "relevance": 0.443969,
#               "text": "starship"
#             },
#             {
#               "relevance": 0.441799,
#               "text": "victory"
#             },
#             {
#               "relevance": 0.437824,
#               "text": "galaxy"
#             },
#             {
#               "relevance": 0.432092,
#               "text": "period"
#             },
#             {
#               "relevance": 0.429238,
#               "text": "battle"
#             },
#             {
#               "relevance": 0.428916,
#               "text": "home"
#             },
#             {
#               "relevance": 0.428498,
#               "text": "people"
#             }
#           ]
#         },
#         "html": "<?xml version='1.0' encoding='UTF-8' standalone='yes'?><html>\n<head>\n    <meta content=\"text/html; charset=UTF-8\" http-equiv=\"Content-Type\"/>\n    \n    <title>Star Wars: Episode IV - A New Hope (Opening Crawl)</title>\n\n\n</head>\n<body>\n\n\n    <article>\n        <h1>Star Wars: Episode IV - A New Hope (Opening Crawl)</h1>\n        <p>\n            It is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n        </p><p>\n            During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n        </p><p>\n            Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...\n        </p>\n    </article>\n</body></html>",
#         "enriched_text_elements": {
#           "statusCode": 200,
#           "body": {
#             "language": "en",
#             "usage": {
#               "text_units": 1,
#               "text_characters": 1,
#               "features": 1
#             }
#           }
#         },
#         "text": "Star Wars: Episode IV - A New Hope (Opening Crawl)\n\nStar Wars: Episode IV - A New Hope (Opening Crawl)\n\nIt is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n\nDuring the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n\nPursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#         "extracted_metadata": {
#           "title": "Star Wars: Episode IV - A New Hope (Opening Crawl)"
#         }
#       }
#     },
#     {
#       "step": "normalizations_output",
#       "snapshot": {
#         "enriched_text": {
#           "entities": [],
#           "categories": [
#             {
#               "label": "/art and entertainment/movies and tv/movies",
#               "score": 0.584247
#             },
#             {
#               "label": "/society/unrest and war",
#               "score": 0.517031
#             },
#             {
#               "label": "/law, govt and politics/armed forces/army",
#               "score": 0.215561
#             }
#           ],
#           "sentiment": {
#             "document": {
#               "label": "negative",
#               "score": -0.575489
#             }
#           },
#           "concepts": [
#             {
#               "relevance": 0.98887,
#               "text": "Star Wars Episode IV: A New Hope",
#               "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_IV:_A_New_Hope"
#             },
#             {
#               "relevance": 0.985705,
#               "text": "Star Wars",
#               "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars"
#             },
#             {
#               "relevance": 0.90639,
#               "text": "Rebel Alliance",
#               "dbpedia_resource": "http://dbpedia.org/resource/Rebel_Alliance"
#             },
#             {
#               "relevance": 0.805771,
#               "text": "Luke Skywalker",
#               "dbpedia_resource": "http://dbpedia.org/resource/Luke_Skywalker"
#             },
#             {
#               "relevance": 0.801062,
#               "text": "Star Wars Episode V: The Empire Strikes Back",
#               "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_V:_The_Empire_Strikes_Back"
#             },
#             {
#               "relevance": 0.777337,
#               "text": "Darth Vader",
#               "dbpedia_resource": "http://dbpedia.org/resource/Darth_Vader"
#             },
#             {
#               "relevance": 0.77159,
#               "text": "Star Wars Episode VI: Return of the Jedi",
#               "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_VI:_Return_of_the_Jedi"
#             },
#             {
#               "relevance": 0.748553,
#               "text": "Grand Moff Tarkin",
#               "dbpedia_resource": "http://dbpedia.org/resource/Grand_Moff_Tarkin"
#             }
#           ],
#           "keywords": [
#             {
#               "relevance": 0.920159,
#               "text": "Opening Crawl"
#             },
#             {
#               "relevance": 0.785031,
#               "text": "New Hope"
#             },
#             {
#               "relevance": 0.775799,
#               "text": "Princess Leia races"
#             },
#             {
#               "relevance": 0.771384,
#               "text": "Star Wars"
#             },
#             {
#               "relevance": 0.767527,
#               "text": "evil Galactic Empire"
#             },
#             {
#               "relevance": 0.747615,
#               "text": "armored space station"
#             },
#             {
#               "relevance": 0.669776,
#               "text": "Rebel spaceships"
#             },
#             {
#               "relevance": 0.656828,
#               "text": "Rebel spies"
#             },
#             {
#               "relevance": 0.609404,
#               "text": "sinister agents"
#             },
#             {
#               "relevance": 0.600682,
#               "text": "civil war"
#             },
#             {
#               "relevance": 0.597836,
#               "text": "hidden base"
#             },
#             {
#               "relevance": 0.594694,
#               "text": "ultimate weapon"
#             },
#             {
#               "relevance": 0.582765,
#               "text": "secret plans"
#             },
#             {
#               "relevance": 0.582596,
#               "text": "entire planet"
#             },
#             {
#               "relevance": 0.574413,
#               "text": "DEATH STAR"
#             },
#             {
#               "relevance": 0.465394,
#               "text": "custodian"
#             },
#             {
#               "relevance": 0.462247,
#               "text": "Episode"
#             },
#             {
#               "relevance": 0.443969,
#               "text": "starship"
#             },
#             {
#               "relevance": 0.441799,
#               "text": "victory"
#             },
#             {
#               "relevance": 0.437824,
#               "text": "galaxy"
#             },
#             {
#               "relevance": 0.432092,
#               "text": "period"
#             },
#             {
#               "relevance": 0.429238,
#               "text": "battle"
#             },
#             {
#               "relevance": 0.428916,
#               "text": "home"
#             },
#             {
#               "relevance": 0.428498,
#               "text": "people"
#             }
#           ]
#         },
#         "html": "<?xml version='1.0' encoding='UTF-8' standalone='yes'?><html>\n<head>\n    <meta content=\"text/html; charset=UTF-8\" http-equiv=\"Content-Type\"/>\n    \n    <title>Star Wars: Episode IV - A New Hope (Opening Crawl)</title>\n\n\n</head>\n<body>\n\n\n    <article>\n        <h1>Star Wars: Episode IV - A New Hope (Opening Crawl)</h1>\n        <p>\n            It is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n        </p><p>\n            During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n        </p><p>\n            Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...\n        </p>\n    </article>\n</body></html>",
#         "enriched_text_elements": {
#           "statusCode": 200,
#           "body": {
#             "language": "en",
#             "usage": {
#               "text_units": 1,
#               "text_characters": 1,
#               "features": 1
#             }
#           }
#         },
#         "text": "Star Wars: Episode IV - A New Hope (Opening Crawl)\n\nStar Wars: Episode IV - A New Hope (Opening Crawl)\n\nIt is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n\nDuring the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n\nPursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#         "extracted_metadata": {
#           "title": "Star Wars: Episode IV - A New Hope (Opening Crawl)"
#         }
#       }
#     },
#     {
#       "step": "filtering_output",
#       "snapshot": {
#         "enriched_text": {
#           "entities": [],
#           "categories": [
#             {
#               "label": "/art and entertainment/movies and tv/movies",
#               "score": 0.584247
#             },
#             {
#               "label": "/society/unrest and war",
#               "score": 0.517031
#             },
#             {
#               "label": "/law, govt and politics/armed forces/army",
#               "score": 0.215561
#             }
#           ],
#           "sentiment": {
#             "document": {
#               "label": "negative",
#               "score": -0.575489
#             }
#           },
#           "concepts": [
#             {
#               "relevance": 0.98887,
#               "text": "Star Wars Episode IV: A New Hope",
#               "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_IV:_A_New_Hope"
#             },
#             {
#               "relevance": 0.985705,
#               "text": "Star Wars",
#               "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars"
#             },
#             {
#               "relevance": 0.90639,
#               "text": "Rebel Alliance",
#               "dbpedia_resource": "http://dbpedia.org/resource/Rebel_Alliance"
#             },
#             {
#               "relevance": 0.805771,
#               "text": "Luke Skywalker",
#               "dbpedia_resource": "http://dbpedia.org/resource/Luke_Skywalker"
#             },
#             {
#               "relevance": 0.801062,
#               "text": "Star Wars Episode V: The Empire Strikes Back",
#               "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_V:_The_Empire_Strikes_Back"
#             },
#             {
#               "relevance": 0.777337,
#               "text": "Darth Vader",
#               "dbpedia_resource": "http://dbpedia.org/resource/Darth_Vader"
#             },
#             {
#               "relevance": 0.77159,
#               "text": "Star Wars Episode VI: Return of the Jedi",
#               "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_VI:_Return_of_the_Jedi"
#             },
#             {
#               "relevance": 0.748553,
#               "text": "Grand Moff Tarkin",
#               "dbpedia_resource": "http://dbpedia.org/resource/Grand_Moff_Tarkin"
#             }
#           ],
#           "keywords": [
#             {
#               "relevance": 0.920159,
#               "text": "Opening Crawl"
#             },
#             {
#               "relevance": 0.785031,
#               "text": "New Hope"
#             },
#             {
#               "relevance": 0.775799,
#               "text": "Princess Leia races"
#             },
#             {
#               "relevance": 0.771384,
#               "text": "Star Wars"
#             },
#             {
#               "relevance": 0.767527,
#               "text": "evil Galactic Empire"
#             },
#             {
#               "relevance": 0.747615,
#               "text": "armored space station"
#             },
#             {
#               "relevance": 0.669776,
#               "text": "Rebel spaceships"
#             },
#             {
#               "relevance": 0.656828,
#               "text": "Rebel spies"
#             },
#             {
#               "relevance": 0.609404,
#               "text": "sinister agents"
#             },
#             {
#               "relevance": 0.600682,
#               "text": "civil war"
#             },
#             {
#               "relevance": 0.597836,
#               "text": "hidden base"
#             },
#             {
#               "relevance": 0.594694,
#               "text": "ultimate weapon"
#             },
#             {
#               "relevance": 0.582765,
#               "text": "secret plans"
#             },
#             {
#               "relevance": 0.582596,
#               "text": "entire planet"
#             },
#             {
#               "relevance": 0.574413,
#               "text": "DEATH STAR"
#             },
#             {
#               "relevance": 0.465394,
#               "text": "custodian"
#             },
#             {
#               "relevance": 0.462247,
#               "text": "Episode"
#             },
#             {
#               "relevance": 0.443969,
#               "text": "starship"
#             },
#             {
#               "relevance": 0.441799,
#               "text": "victory"
#             },
#             {
#               "relevance": 0.437824,
#               "text": "galaxy"
#             },
#             {
#               "relevance": 0.432092,
#               "text": "period"
#             },
#             {
#               "relevance": 0.429238,
#               "text": "battle"
#             },
#             {
#               "relevance": 0.428916,
#               "text": "home"
#             },
#             {
#               "relevance": 0.428498,
#               "text": "people"
#             }
#           ]
#         },
#         "html": "<?xml version='1.0' encoding='UTF-8' standalone='yes'?><html>\n<head>\n    <meta content=\"text/html; charset=UTF-8\" http-equiv=\"Content-Type\"/>\n    \n    <title>Star Wars: Episode IV - A New Hope (Opening Crawl)</title>\n\n\n</head>\n<body>\n\n\n    <article>\n        <h1>Star Wars: Episode IV - A New Hope (Opening Crawl)</h1>\n        <p>\n            It is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n        </p><p>\n            During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n        </p><p>\n            Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...\n        </p>\n    </article>\n</body></html>",
#         "enriched_text_elements": {
#           "statusCode": 200,
#           "body": {
#             "language": "en",
#             "usage": {
#               "text_units": 1,
#               "text_characters": 1,
#               "features": 1
#             }
#           }
#         },
#         "text": "Star Wars: Episode IV - A New Hope (Opening Crawl)\n\nStar Wars: Episode IV - A New Hope (Opening Crawl)\n\nIt is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n\nDuring the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n\nPursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#         "extracted_metadata": {
#           "title": "Star Wars: Episode IV - A New Hope (Opening Crawl)"
#         }
#       }
#     }
#   ]
# }

# %% [markdown]
# ### Analyze test output
#
# The results returned by the service contain a _snapshot_ of the information extracted at each step of processing - document conversions, enrichments and normalizations. We are interested in the output of applying enrichments (`"enrichments_output"`) or after normalizing them (`"normalizations_output"`). These should be identical if no post-processing/normalizations were specified in the configuration.

# %%
# Take a closer look at the results from the "enrichments_output" or "normalizations_output" step
output = next((s["snapshot"] for s in res["snapshots"] if s["step"] == "enrichments_output"), None)
print(json.dumps(output, indent=2))
# Out:
# {
#   "enriched_text": {
#     "entities": [],
#     "categories": [
#       {
#         "label": "/art and entertainment/movies and tv/movies",
#         "score": 0.584247
#       },
#       {
#         "label": "/society/unrest and war",
#         "score": 0.517031
#       },
#       {
#         "label": "/law, govt and politics/armed forces/army",
#         "score": 0.215561
#       }
#     ],
#     "sentiment": {
#       "document": {
#         "label": "negative",
#         "score": -0.575489
#       }
#     },
#     "concepts": [
#       {
#         "relevance": 0.98887,
#         "text": "Star Wars Episode IV: A New Hope",
#         "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_IV:_A_New_Hope"
#       },
#       {
#         "relevance": 0.985705,
#         "text": "Star Wars",
#         "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars"
#       },
#       {
#         "relevance": 0.90639,
#         "text": "Rebel Alliance",
#         "dbpedia_resource": "http://dbpedia.org/resource/Rebel_Alliance"
#       },
#       {
#         "relevance": 0.805771,
#         "text": "Luke Skywalker",
#         "dbpedia_resource": "http://dbpedia.org/resource/Luke_Skywalker"
#       },
#       {
#         "relevance": 0.801062,
#         "text": "Star Wars Episode V: The Empire Strikes Back",
#         "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_V:_The_Empire_Strikes_Back"
#       },
#       {
#         "relevance": 0.777337,
#         "text": "Darth Vader",
#         "dbpedia_resource": "http://dbpedia.org/resource/Darth_Vader"
#       },
#       {
#         "relevance": 0.77159,
#         "text": "Star Wars Episode VI: Return of the Jedi",
#         "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_VI:_Return_of_the_Jedi"
#       },
#       {
#         "relevance": 0.748553,
#         "text": "Grand Moff Tarkin",
#         "dbpedia_resource": "http://dbpedia.org/resource/Grand_Moff_Tarkin"
#       }
#     ],
#     "keywords": [
#       {
#         "relevance": 0.920159,
#         "text": "Opening Crawl"
#       },
#       {
#         "relevance": 0.785031,
#         "text": "New Hope"
#       },
#       {
#         "relevance": 0.775799,
#         "text": "Princess Leia races"
#       },
#       {
#         "relevance": 0.771384,
#         "text": "Star Wars"
#       },
#       {
#         "relevance": 0.767527,
#         "text": "evil Galactic Empire"
#       },
#       {
#         "relevance": 0.747615,
#         "text": "armored space station"
#       },
#       {
#         "relevance": 0.669776,
#         "text": "Rebel spaceships"
#       },
#       {
#         "relevance": 0.656828,
#         "text": "Rebel spies"
#       },
#       {
#         "relevance": 0.609404,
#         "text": "sinister agents"
#       },
#       {
#         "relevance": 0.600682,
#         "text": "civil war"
#       },
#       {
#         "relevance": 0.597836,
#         "text": "hidden base"
#       },
#       {
#         "relevance": 0.594694,
#         "text": "ultimate weapon"
#       },
#       {
#         "relevance": 0.582765,
#         "text": "secret plans"
#       },
#       {
#         "relevance": 0.582596,
#         "text": "entire planet"
#       },
#       {
#         "relevance": 0.574413,
#         "text": "DEATH STAR"
#       },
#       {
#         "relevance": 0.465394,
#         "text": "custodian"
#       },
#       {
#         "relevance": 0.462247,
#         "text": "Episode"
#       },
#       {
#         "relevance": 0.443969,
#         "text": "starship"
#       },
#       {
#         "relevance": 0.441799,
#         "text": "victory"
#       },
#       {
#         "relevance": 0.437824,
#         "text": "galaxy"
#       },
#       {
#         "relevance": 0.432092,
#         "text": "period"
#       },
#       {
#         "relevance": 0.429238,
#         "text": "battle"
#       },
#       {
#         "relevance": 0.428916,
#         "text": "home"
#       },
#       {
#         "relevance": 0.428498,
#         "text": "people"
#       }
#     ]
#   },
#   "html": "<?xml version='1.0' encoding='UTF-8' standalone='yes'?><html>\n<head>\n    <meta content=\"text/html; charset=UTF-8\" http-equiv=\"Content-Type\"/>\n    \n    <title>Star Wars: Episode IV - A New Hope (Opening Crawl)</title>\n\n\n</head>\n<body>\n\n\n    <article>\n        <h1>Star Wars: Episode IV - A New Hope (Opening Crawl)</h1>\n        <p>\n            It is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n        </p><p>\n            During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n        </p><p>\n            Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...\n        </p>\n    </article>\n</body></html>",
#   "enriched_text_elements": {
#     "statusCode": 200,
#     "body": {
#       "language": "en",
#       "usage": {
#         "text_units": 1,
#         "text_characters": 1,
#         "features": 1
#       }
#     }
#   },
#   "text": "Star Wars: Episode IV - A New Hope (Opening Crawl)\n\nStar Wars: Episode IV - A New Hope (Opening Crawl)\n\nIt is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n\nDuring the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n\nPursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#   "extracted_metadata": {
#     "title": "Star Wars: Episode IV - A New Hope (Opening Crawl)"
#   }
# }

# %% [markdown]
# Answer the following questions based on the output above. Note that it contains the input HTML, extracted text and metadata as well as the actual enrichment results (`"enriched_text"` block).
#
# #### Sentiment
#
# **Q**: What is the overall sentiment detected in this text? Mention the `type` (positive/negative) and `score`.<br />
# (_Hint: Look for the `"docSentiment"` key in the output._)
#
# **A**: Negaitive, score: -0.575489
#
#
# #### Concepts
#
# **Q**: List 3 concepts that have been identified with a relevance > 0.5. Note that not all concepts here may be present directly in the text, some may have been inferred by Watson.<br />
# (_Hint: Look for `"concepts"`._)
#
# **A**: Star Wars Episode IV: A New Hope", "Rebel Alliance", "Luke Skywalker"
#
#
# #### Relations
#
# Each relation is essentially a deeper analysis of a sentence (or part of a sentence). Here is a sample relation:
# ```json
# {
#   "sentence": " During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.",
#   "subject": {
#     "text": "Rebel spies",
#     "keywords": [
#       {
#         "text": "Rebel spies"
#       }
#     ]
#   },
#   "action": {
#     "text": "managed to steal",
#     "lemmatized": "manage to steal",
#     "verb": {
#       "text": "steal",
#       "tense": "future"
#     }
#   },
#   "object": {
#     "text": "secret plans",
#     "keywords": [
#       {
#         "text": "secret plans"
#       }
#     ]
#   }
#  }
# ```
#
# In this case, Watson seems to have done a pretty good job of extracting some meaning from the sentence.
#
# **Q**: Find a relation where the extracted meaning is not as accurate, or not what you would've expected. List the `sentence`, `subject`, `action` and `object` parts as identified, and what you would've marked instead.<br />
# (_Hint: Look for `"relations"`._)
#
# **A**:
# {
#         "type": "affectedBy",
#         "score": 0.316489,
#         "arguments": [
#           {
#             "text": "people",
#             "entities": [
#               {
#                 "text": "people",
#                 "type": "Person"
#               }
#             ],
#             "location": [
#               562,
#               568
#             ]
#           },
#           {
#             "text": "stolen",
#             "entities": [
#               {
#                 "text": "stolen",
#                 "type": "Crime"
#               }
#             ],
#             "location": [
#               531,
#               537
#             ]
#           }
#         ],
#         "sentence": "Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy..."
#       }
#
# I would've had the 'plans' as the 'entities' that were 'stolen'.
#
# #### Keywords
#
# You may have noticed that Watson identifies some `"keywords"` in the relations, e.g. `"Rebel spies"` and `"secret plans"` in the Star Wars example above. The output also contains a list of all keywords at the top level, for your convenience, along with their relevance to the document and sentiment conveyed. Let's visualize these keywords as a word cloud!
#
# Note: We'll be using this handy [worldcoud library](https://github.com/amueller/word_cloud) to generate the visualization. So you will need to install it first:
# ```bash
# pip install wordcloud
# ```

# %%
# Visualize keywords by relevance as a wordcloud
from wordcloud import WordCloud

wc_data = { w["text"]: w["relevance"] for w in output["enriched_text"]["keywords"] }
wc = WordCloud(width=400, height=300, scale=2, background_color="white", colormap="Vega10")
wc.generate_from_frequencies(wc_data)  # use precomputed relevance instead of frequencies

plt.figure(figsize=(4, 3), dpi=200)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
# Out:
# /nfs/2018/t/tryan/anaconda3/envs/aind/lib/python3.5/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: The Vega10 colormap was deprecated in version 2.0. Use tab10 instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# (-0.5, 799.5, 599.5, -0.5)

# %% [markdown]
# Feel free to play with this visualization and improve it. What about using a different metric instead of relevance, e.g. direct word frequencies that the wordcloud library computes by default?
#
# #### Other results
#
# Watson's output also includes processed results from other enrichments that were applied to the text, including entities and taxonomy (what topic or category does this text relate to).
#
# ```json
# "taxonomy": [
#   {
#     "label": "/art and entertainment/movies and tv/movies",
#     "score": 0.584247,
#     "confident": false
#   },
#   {
#     "label": "/society/unrest and war",
#     "score": 0.517031,
#     "confident": false
#   },
#   {
#     "confident": false,
#     "label": "/law, govt and politics/armed forces/army",
#     "score": 0.215561
#   }
# ],
# ```
#
# Get a good sense of all the different pieces of information available in the results. Start thinking about which ones will be useful for looking up answers to questions, and how you might use them.

# %% [markdown]
# ## 2. Ingest documents
#
# ### Create a collection
#
# A _collection_ is used to organize documents of the same kind. For instance, you may want to create a collection of book reviews, or a collection of Wikipedia articles, but it may not make much sense to mix the two groups. This allows Watson to make meaningful inferences over the set of documents, find commonalities and identify important concepts.
#
# Let's create one called "Story Chunks".

# %%
# Prepare a collection of documents to use
col, col_id = helper.fetch_object(discovery, "collection", "Story Chunks", environment_id=env_id,
    create=True, create_args=dict(
        environment_id=env_id, configuration_id=cfg_id,
        description="Stories and plots split up into chunks suitable for answering"
    ))
print(json.dumps(col, indent=2))
# Out:
# Found collection: Story Chunks (4ca4b241-cb8d-4ee8-a5e5-44692355840f)
# {
#   "disk_usage": {
#     "used_bytes": 162
#   },
#   "updated": "2018-08-07T21:02:15.220Z",
#   "collection_id": "4ca4b241-cb8d-4ee8-a5e5-44692355840f",
#   "language": "en",
#   "status": "active",
#   "created": "2018-08-07T19:42:00.581Z",
#   "training_status": {
#     "minimum_examples_added": false,
#     "notices": 0,
#     "sufficient_label_diversity": false,
#     "total_examples": 0,
#     "data_updated": "",
#     "minimum_queries_added": false,
#     "successfully_trained": "",
#     "available": false,
#     "processing": false
#   },
#   "crawl_status": {
#     "source_crawl": {
#       "status": "not_configured"
#     }
#   },
#   "document_counts": {
#     "available": 0,
#     "failed": 0,
#     "processing": 0
#   },
#   "name": "Story Chunks",
#   "configuration_id": "0fa6ce41-4d8d-4d06-be9b-571991f5140b",
#   "description": "Stories and plots split up into chunks suitable for answering"
# }

# %% [markdown]
# Once you have created a collection, you should be able to view it using the Discovery Service tool. To open, go to the **Manage** tab for your service instance, and click the **Launch tool** button.
#
# <img src="images/discovery-manage.png" alt="Discovery service - Manage tab" width="800" />

# %% [markdown]
# Here you should see the "Story Chunks" collection you just created.
#
# <img src="images/discovery-tooling.png" alt="Discovery service - Tool showing collections" width="800" />
#
# You can open the collection to view more details about it. If you need to modify configuration options, click the **Switch** link and create a new configuration (the default one cannot be changed).

# %% [markdown]
# ### Add documents
#
# Okay, now that we have everything set up, let's add a set of "documents" we want Watson to look up answers from, using the Python SDK. Note that Watson treats each "document" as a unit of text that is returned as the result of a query. But we want to retrieve a paragraph of text for each question. So, let's split each file up into individual paragraphs. We will use the [BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/) library for this purpose.
#
# _**Note**: You could also add and manage documents in the collection using the Discovery tool, but you would have to split paragraphs up into separate files._
#
# _**Note**: We have provided a set of files (`data/Star-Wars/*.html`) with summary plots for Star Wars movies, but you are free to use a collection of your choice. Open one of the files in a text editor to see how the paragraphs are delimited using `<p>...</p>` tags - this is how the code block below split paragraphs into separate "documents"._

# %%
# Add documents to collection
import time

doc_ids = []  # to store the generated id for each document added
for filename in glob.glob(os.path.join(data_dir, "Star-Wars", "*.html")):
    print("Adding file:", filename)
    with open(filename, "r") as f:
        # Split each individual <p> into its own "document"
        doc = f.read()
        soup = BeautifulSoup(doc, 'html.parser')
        with open("meta.json", "w+") as meta:
            json.dump({"title": soup.title.get_text(strip=True)}, meta)
            for i, p in enumerate(soup.find_all('p')):
                with open("temp.json", "w+") as jsn:
                    json.dump({"text": p.get_text(strip=True)}, jsn)
                    doc_info = discovery.add_document(environment_id=env_id, collection_id=col_id,
                        file= "temp.json",
                        filename = "{} {}".format(filename, i),
                        file_content_type = "application/json")
                doc_ids.append(doc_info["document_id"])
    time.sleep(30)
print("Total", len(doc_ids), "documents added.")
# Out:
# Adding file: data/Star-Wars/Episode-III_Revenge-of-the-Sith.html
# Adding file: data/Star-Wars/Episode-VII_The-Force-Awakens.html
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/envs/aind/lib/python3.5/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-c8bdbd6a9c84> in <module>()
#      17                         file= "temp.json",
#      18                         filename = "{} {}".format(filename, i),
# ---> 19                         file_content_type = "application/json")
#      20                 doc_ids.append(doc_info["document_id"])
#      21     time.sleep(30)
#
# ~/anaconda3/envs/aind/lib/python3.5/site-packages/watson_developer_cloud/discovery_v1.py in add_document(self, environment_id, collection_id, file, metadata, file_content_type, filename, **kwargs)
#    1032             files={'file': file_tuple,
#    1033                    'metadata': metadata_tuple},
# -> 1034             accept_json=True)
#    1035         return response
#    1036
#
# ~/anaconda3/envs/aind/lib/python3.5/site-packages/watson_developer_cloud/watson_service.py in request(self, method, url, accept_json, headers, params, json, data, files, **kwargs)
#     443                                     headers=headers,
#     444                                     params=params, data=data, files=files,
# --> 445                                     **kwargs)
#     446
#     447         if 200 <= response.status_code <= 299:
#
# ~/anaconda3/envs/aind/lib/python3.5/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~/anaconda3/envs/aind/lib/python3.5/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     510         }
#     511         send_kwargs.update(settings)
# --> 512         resp = self.send(prep, **send_kwargs)
#     513
#     514         return resp
#
# ~/anaconda3/envs/aind/lib/python3.5/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     620
#     621         # Send the request
# --> 622         r = adapter.send(request, **kwargs)
#     623
#     624         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/envs/aind/lib/python3.5/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     443                     decode_content=False,
#     444                     retries=self.max_retries,
# --> 445                     timeout=timeout
#     446                 )
#     447
#
# ~/anaconda3/envs/aind/lib/python3.5/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/anaconda3/envs/aind/lib/python3.5/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 2.6 and older, Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# ~/anaconda3/envs/aind/lib/python3.5/http/client.py in getresponse(self)
#    1196         try:
#    1197             try:
# -> 1198                 response.begin()
#    1199             except ConnectionError:
#    1200                 self.close()
#
# ~/anaconda3/envs/aind/lib/python3.5/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# ~/anaconda3/envs/aind/lib/python3.5/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# ~/anaconda3/envs/aind/lib/python3.5/socket.py in readinto(self, b)
#     574         while True:
#     575             try:
# --> 576                 return self._sock.recv_into(b)
#     577             except timeout:
#     578                 self._timeout_occurred = True
#
# ~/anaconda3/envs/aind/lib/python3.5/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     283     def recv_into(self, *args, **kwargs):
#     284         try:
# --> 285             return self.connection.recv_into(*args, **kwargs)
#     286         except OpenSSL.SSL.SysCallError as e:
#     287             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# ~/anaconda3/envs/aind/lib/python3.5/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1811             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1812         else:
# -> 1813             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1814         self._raise_ssl_error(self._ssl, result)
#    1815
#
# KeyboardInterrupt:

# %% [markdown]
# If you look at the collection details, you may notice that the `"document_counts"` field now shows some documents as `available` or `processing`. Once processing is complete, you should see all the documents under the `available` count.

# %%
# View collection details to verify all documents have been processed
col, col_id = helper.fetch_object(discovery, "collection", "Story Chunks", environment_id=env_id)
print(json.dumps(col, indent=2))
# Out:
# Found collection: Story Chunks (4ca4b241-cb8d-4ee8-a5e5-44692355840f)
# {
#   "disk_usage": {
#     "used_bytes": 1011481
#   },
#   "updated": "2018-08-07T21:02:15.220Z",
#   "collection_id": "4ca4b241-cb8d-4ee8-a5e5-44692355840f",
#   "language": "en",
#   "status": "active",
#   "created": "2018-08-07T19:42:00.581Z",
#   "training_status": {
#     "minimum_examples_added": false,
#     "notices": 0,
#     "sufficient_label_diversity": false,
#     "total_examples": 0,
#     "data_updated": "",
#     "minimum_queries_added": false,
#     "successfully_trained": "",
#     "available": false,
#     "processing": false
#   },
#   "crawl_status": {
#     "source_crawl": {
#       "status": "not_configured"
#     }
#   },
#   "document_counts": {
#     "available": 8,
#     "failed": 27,
#     "processing": 0
#   },
#   "name": "Story Chunks",
#   "configuration_id": "0fa6ce41-4d8d-4d06-be9b-571991f5140b",
#   "description": "Stories and plots split up into chunks suitable for answering"
# }

# %% [markdown]
# So, what did the Discovery service learn? If you list the fields extracted from the set of documents in the collection as part of the enrichment process, you'll see familiar fields like `concepts`, `entities` and `keywords` that were returned in the test analysis.

# %%
# List all fields extracted
discovery.list_collection_fields(environment_id=env_id, collection_id=col_id)
# Out:
# {'fields': [{'field': 'enriched_text.relations.arguments.entities.disambiguation',
#    'type': 'nested'},
#   {'field': 'extracted_metadata.title', 'type': 'string'},
#   {'field': 'enriched_text.entities.sentiment.score', 'type': 'double'},
#   {'field': 'enriched_text.sentiment.document.label', 'type': 'string'},
#   {'field': 'enriched_text.concepts.dbpedia_resource', 'type': 'string'},
#   {'field': 'extracted_metadata.file_type', 'type': 'string'},
#   {'field': 'enriched_text.relations.score', 'type': 'double'},
#   {'field': 'enriched_text.relations.arguments.entities.text',
#    'type': 'string'},
#   {'field': 'enriched_text.concepts.text', 'type': 'string'},
#   {'field': 'enriched_text.relations.arguments.entities.disambiguation.subtype',
#    'type': 'string'},
#   {'field': 'enriched_text.keywords.relevance', 'type': 'double'},
#   {'field': 'enriched_text.concepts.relevance', 'type': 'double'},
#   {'field': 'enriched_text.relations.sentence', 'type': 'string'},
#   {'field': 'enriched_text.categories.score', 'type': 'double'},
#   {'field': 'enriched_text.keywords', 'type': 'nested'},
#   {'field': 'enriched_text.relations', 'type': 'nested'},
#   {'field': 'enriched_text.entities.sentiment.label', 'type': 'string'},
#   {'field': 'enriched_text.relations.type', 'type': 'string'},
#   {'field': 'enriched_text.entities.relevance', 'type': 'double'},
#   {'field': 'text', 'type': 'string'},
#   {'field': 'enriched_text.entities.count', 'type': 'double'},
#   {'field': 'enriched_text.entities.sentiment', 'type': 'nested'},
#   {'field': 'enriched_text.sentiment.document', 'type': 'nested'},
#   {'field': 'enriched_text.keywords.text', 'type': 'string'},
#   {'field': 'enriched_text.entities.text', 'type': 'string'},
#   {'field': 'enriched_text.entities', 'type': 'nested'},
#   {'field': 'enriched_text.entities.disambiguation.name', 'type': 'string'},
#   {'field': 'enriched_text.categories.label', 'type': 'string'},
#   {'field': 'id', 'type': 'string'},
#   {'field': 'enriched_text.relations.arguments.location', 'type': 'double'},
#   {'field': 'enriched_text.concepts', 'type': 'nested'},
#   {'field': 'enriched_text.entities.disambiguation', 'type': 'nested'},
#   {'field': 'enriched_text.entities.type', 'type': 'string'},
#   {'field': 'extracted_metadata.sha1', 'type': 'string'},
#   {'field': 'enriched_text.relations.arguments.text', 'type': 'string'},
#   {'field': 'enriched_text.relations.arguments', 'type': 'nested'},
#   {'field': 'enriched_text.relations.arguments.entities.type',
#    'type': 'string'},
#   {'field': 'enriched_text', 'type': 'nested'},
#   {'field': 'enriched_text.categories', 'type': 'nested'},
#   {'field': 'extracted_metadata', 'type': 'nested'},
#   {'field': 'enriched_text.entities.disambiguation.subtype', 'type': 'string'},
#   {'field': 'enriched_text.sentiment', 'type': 'nested'},
#   {'field': 'html', 'type': 'string'},
#   {'field': 'enriched_text.entities.disambiguation.dbpedia_resource',
#    'type': 'string'},
#   {'field': 'enriched_text.sentiment.document.score', 'type': 'double'},
#   {'field': 'extracted_metadata.filename', 'type': 'string'},
#   {'field': 'enriched_text.relations.arguments.entities', 'type': 'nested'}]}

# %% [markdown]
# ### Test query
#
# Let's perform a simple query to see if the service can fetch the proper document for us:
# > _Look for all paragraphs that have a relation (sentence) with "Jar Jar" as the subject, and return the title and text._

# %%
# A simple query
results = discovery.query(environment_id=env_id, collection_id=col_id,
    query_options={
        "query": "enriched_text.relations.subject.text:\"\"",
        "return": "metadata.title,text"
    })
print(json.dumps(results, indent=2))
# Out:
# {
#   "results": [
#     {
#       "html": "<?xml version='1.0' encoding='UTF-8' standalone='yes'?><html>\n<head>\n    <meta content=\"text/html; charset=UTF-8\" http-equiv=\"Content-Type\"/>\n    <title>Star Wars: Episode I - The Phantom Menace</title>\n\n</head>\n<body>\n\n    <article>\n        <h1>Star Wars: Episode I - The Phantom Menace</h1>\n        <p>\n            Supreme Chancellor Valorum, leader of the Galactic Republic, dispatches Jedi Knight Qui-Gon Jinn and his apprentice, Obi-Wan Kenobi, to negotiate with the Trade Federation leadership to end a blockade of battleships around the planet Naboo. Darth Sidious, a Sith Lord and the Trade Federation's secret adviser, orders Federation Viceroy Nute Gunray to kill the Jedi and invade Naboo with an army of battle droids. The Jedi escape and flee to Naboo, where Qui-Gon saves a Gungan outcast, Jar Jar Binks, from being run over and killed by a droid tank during the invasion. Indebted to the Jedi, Jar Jar leads them to an underwater Gungan city. The Jedi unsuccessfully try to persuade the Gungan leader, Boss Nass, into helping the people of Naboo, though they are able to obtain transportation to Theed, the capital city on the surface. They rescue Queen Amidala, the ruler of the Naboo people, and escape the planet on her royal starship, which is damaged as they pass the Federation blockade.\n        </p><p>\n            Amidala's ship is unable to sustain its hyperdrive and lands for repairs on the desert planet Tatooine. Qui-Gon, Jar Jar, astromech droid R2-D2, and Amidala (in disguise as the handmaiden Padm\u00e9) visit the settlement of Mos Espa to buy new parts at a junk shop. They meet the shop's owner Watto and his nine-year-old slave, Anakin Skywalker, who is a gifted pilot and engineer and has created a protocol droid called C-3PO. Qui-Gon senses a strong presence of the Force within Anakin and is convinced that he is the \"chosen one\" of Jedi prophecy who will bring balance to the Force. Qui-Gon wagers Anakin's freedom with Watto in a Podrace, which Anakin wins. Anakin joins the group to be trained as a Jedi, leaving his mother Shmi behind. En route to their starship, Qui-Gon briefly duels with Darth Maul, Darth Sidious's apprentice, who was sent to capture Amidala. Qui-Gon quits the duel and escapes by leaping onto the open boarding ramp of the departing starship.\n        </p><p>\n            Qui-Gon and Obi-Wan escort Amidala to the Republic capital planet of Coruscant so that she can plead her people's case to Chancellor Valorum and the Galactic Senate. Qui-Gon asks the Jedi Council for permission to train Anakin as a Jedi, but the Council refuses, concerned that Anakin is vulnerable to the dark side. Undaunted, Qui-Gon vows to train Anakin himself. Meanwhile, Naboo's Senator Palpatine persuades Amidala to make a vote of no confidence in Valorum to elect a more capable chancellor to resolve the crisis on Naboo. Though she is successful in pushing for the vote, Amidala grows frustrated with the corruption in the Senate and decides to return to Naboo. Qui-Gon and Obi-Wan are ordered by the Jedi Council to accompany the queen to Naboo, as well as to confirm the return of the Sith, whom they believe to be extinct.\n        </p><p>\n            On Naboo, Padm\u00e9 reveals herself to the Gungans as Queen Amidala and persuades them into an alliance against the Trade Federation. Jar Jar leads his people in a battle against the droid army while Padm\u00e9 leads the hunt for Gunray in Theed. During a battle in a starship hangar to free Naboo pilots, Anakin takes shelter in a vacant starfighter and inadvertently triggers its autopilot, joining the battle against the Federation droid control ship in space. Anakin blunders into the hangar of the droid control ship and destroys the ship from within before escaping, deactivating the droid army. Meanwhile, Qui-Gon and Obi-Wan battle Darth Maul, who mortally wounds Qui-Gon before being bisected by Obi-Wan. As he dies, Qui-Gon asks Obi-Wan to train Anak ...
#       "score": 1,
#       "text": "Star Wars: Episode I - The Phantom Menace\n\nStar Wars: Episode I - The Phantom Menace\n\nSupreme Chancellor Valorum, leader of the Galactic Republic, dispatches Jedi Knight Qui-Gon Jinn and his apprentice, Obi-Wan Kenobi, to negotiate with the Trade Federation leadership to end a blockade of battleships around the planet Naboo. Darth Sidious, a Sith Lord and the Trade Federation's secret adviser, orders Federation Viceroy Nute Gunray to kill the Jedi and invade Naboo with an army of battle droids. The Jedi escape and flee to Naboo, where Qui-Gon saves a Gungan outcast, Jar Jar Binks, from being run over and killed by a droid tank during the invasion. Indebted to the Jedi, Jar Jar leads them to an underwater Gungan city. The Jedi unsuccessfully try to persuade the Gungan leader, Boss Nass, into helping the people of Naboo, though they are able to obtain transportation to Theed, the capital city on the surface. They rescue Queen Amidala, the ruler of the Naboo people, and escape the planet on her royal starship, which is damaged as they pass the Federation blockade.\n\nAmidala's ship is unable to sustain its hyperdrive and lands for repairs on the desert planet Tatooine. Qui-Gon, Jar Jar, astromech droid R2-D2, and Amidala (in disguise as the handmaiden Padm\u00e9) visit the settlement of Mos Espa to buy new parts at a junk shop. They meet the shop's owner Watto and his nine-year-old slave, Anakin Skywalker, who is a gifted pilot and engineer and has created a protocol droid called C-3PO. Qui-Gon senses a strong presence of the Force within Anakin and is convinced that he is the \"chosen one\" of Jedi prophecy who will bring balance to the Force. Qui-Gon wagers Anakin's freedom with Watto in a Podrace, which Anakin wins. Anakin joins the group to be trained as a Jedi, leaving his mother Shmi behind. En route to their starship, Qui-Gon briefly duels with Darth Maul, Darth Sidious's apprentice, who was sent to capture Amidala. Qui-Gon quits the duel and escapes by leaping onto the open boarding ramp of the departing starship.\n\nQui-Gon and Obi-Wan escort Amidala to the Republic capital planet of Coruscant so that she can plead her people's case to Chancellor Valorum and the Galactic Senate. Qui-Gon asks the Jedi Council for permission to train Anakin as a Jedi, but the Council refuses, concerned that Anakin is vulnerable to the dark side. Undaunted, Qui-Gon vows to train Anakin himself. Meanwhile, Naboo's Senator Palpatine persuades Amidala to make a vote of no confidence in Valorum to elect a more capable chancellor to resolve the crisis on Naboo. Though she is successful in pushing for the vote, Amidala grows frustrated with the corruption in the Senate and decides to return to Naboo. Qui-Gon and Obi-Wan are ordered by the Jedi Council to accompany the queen to Naboo, as well as to confirm the return of the Sith, whom they believe to be extinct.\n\nOn Naboo, Padm\u00e9 reveals herself to the Gungans as Queen Amidala and persuades them into an alliance against the Trade Federation. Jar Jar leads his people in a battle against the droid army while Padm\u00e9 leads the hunt for Gunray in Theed. During a battle in a starship hangar to free Naboo pilots, Anakin takes shelter in a vacant starfighter and inadvertently triggers its autopilot, joining the battle against the Federation droid control ship in space. Anakin blunders into the hangar of the droid control ship and destroys the ship from within before escaping, deactivating the droid army. Meanwhile, Qui-Gon and Obi-Wan battle Darth Maul, who mortally wounds Qui-Gon before being bisected by Obi-Wan. As he dies, Qui-Gon asks Obi-Wan to train Anakin. Subsequently, Palpatine is elected as the new Supreme Chancellor and Gunray is arrested. The Jedi Council promotes Obi-Wan to the rank of Jedi Knight and reluctantly accepts Anakin as Obi-Wan's apprentice. At a festive ceremony, Padm\u00e9 presents a gift of appreciation and friendship to the Gungans.",
#       "id": "5f02cffb44085eea48607454b74fc711",
#       "enriched_text": {
#         "sentiment": {
#           "document": {
#             "label": "negative",
#             "score": -0.407912
#           }
#         },
#         "keywords": [
#           {
#             "relevance": 0.98239,
#             "text": "Qui-Gon"
#           },
#           {
#             "relevance": 0.980049,
#             "text": "Jedi Knight Qui-Gon"
#           },
#           {
#             "relevance": 0.976236,
#             "text": "Qui-Gon wagers Anakin"
#           },
#           {
#             "relevance": 0.822256,
#             "text": "Jar Jar"
#           },
#           {
#             "relevance": 0.753465,
#             "text": "Naboo"
#           },
#           {
#             "relevance": 0.751727,
#             "text": "Qui-Gon briefly duels"
#           },
#           {
#             "relevance": 0.6897,
#             "text": "Obi-Wan escort Amidala"
#           },
#           {
#             "relevance": 0.672525,
#             "text": "Jedi Council"
#           },
#           {
#             "relevance": 0.638803,
#             "text": "Jar Jar Binks"
#           },
#           {
#             "relevance": 0.609884,
#             "text": "free Naboo pilots"
#           },
#           {
#             "relevance": 0.603494,
#             "text": "Trade Federation"
#           },
#           {
#             "relevance": 0.592616,
#             "text": "planet Naboo"
#           },
#           {
#             "relevance": 0.573384,
#             "text": "astromech droid R2-D2"
#           },
#           {
#             "relevance": 0.57091,
#             "text": "Queen Amidala"
#           },
#           {
#             "relevance": 0.570171,
#             "text": "Obi-Wan battle Darth"
#           },
#           {
#             "relevance": 0.559982,
#             "text": "Naboo people"
#           },
#           {
#             "relevance": 0.551627,
#             "text": "Anakin Skywalker"
#           },
#           {
#             "relevance": 0.524236,
#             "text": "droid army"
#           },
#           {
#             "relevance": 0.52146,
#             "text": "Darth Sidious"
#           },
#           {
#             "relevance": 0.520218,
#             "text": "droid control ship"
#           },
#           {
#             "relevance": 0.518838,
#             "text": "Anakin blunders"
#           },
#           {
#             "relevance": 0.504049,
#             "text": "Supreme Chancellor Valorum"
#           },
#           {
#             "relevance": 0.502602,
#             "text": "Obi-Wan Kenobi"
#           },
#           {
#             "relevance": 0.497032,
#             "text": "Federation Viceroy Nute"
#           },
#           {
#             "relevance": 0.484977,
#             "text": "Trade Federation leadership"
#           },
#           {
#             "relevance": 0.482145,
#             "text": "Jedi escape"
#           },
#           {
#             "relevance": 0.478446,
#             "text": "underwater Gungan city"
#           },
#           {
#             "relevance": 0.478124,
#             "text": "Darth Maul"
#           },
#           {
#             "relevance": 0.467794,
#             "text": "Phantom Menace"
#           },
#           {
#             "relevance": 0.465715,
#             "text": "Star Wars"
#           },
#           {
#             "relevance": 0.464702,
#             "text": "Jedi prophecy"
#           },
#           {
#             "relevance": 0.456329,
#             "text": "desert planet Tatooine"
#           },
#           {
#             "relevance": 0.449018,
#             "text": "new Supreme Chancellor"
#           },
#           {
#             "relevance": 0.448278,
#             "text": "droid tank"
#           },
#           {
#             "relevance": 0.443439,
#             "text": "protocol droid"
#           },
#           {
#             "relevance": 0.434419,
#             "text": "Republic capital planet"
#           },
#           {
#             "relevance": 0.433038,
#             "text": "open boarding ramp"
#           },
#           {
#             "relevance": 0.376051,
#             "text": "Gungan outcast"
#           },
#           {
#             "relevance": 0.369742,
#             "text": "Gungan leader"
#           },
#           {
#             "relevance": 0.359118,
#             "text": "battle droids"
#           },
#           {
#             "relevance": 0.358559,
#             "text": "Federation blockade"
#           },
#           {
#             "relevance": 0.356279,
#             "text": "Sith Lord"
#           },
#           {
#             "relevance": 0.354372,
#             "text": "royal starship"
#           },
#           {
#             "relevance": 0.349801,
#             "text": "capable chancellor"
#           },
#           {
#             "relevance": 0.349191,
#             "text": "Galactic Republic"
#           },
#           {
#             "relevance": 0.345795,
#             "text": "Mos Espa"
#           },
#           {
#             "relevance": 0.343908,
#             "text": "handmaiden Padm\u00e9"
#           },
#           {
#             "relevance": 0.341864,
#             "text": "starship hangar"
#           },
#           {
#             "relevance": 0.34155,
#             "text": "Senator Palpatine"
#           },
#           {
#             "relevance": 0.338001,
#             "text": "Boss Nass"
#           }
#         ],
#         "entities": [
#           {
#             "relevance": 0.826276,
#             "sentiment": {
#               "label": "negative",
#               "score": -0.30645
#             },
#             "text": "Anakin Skywalker",
#             "type": "Person",
#             "count": 12
#           },
#           {
#             "relevance": 0.712955,
#             "sentiment": {
#               "label": "negative",
#               "score": -0.239887
#             },
#             "text": "Qui-Gon",
#             "type": "Person",
#             "count": 6
#           },
#           {
#             "relevance": 0.686669,
#             "sentiment": {
#               "label": "negative",
#               "score": -0.459959
#             },
#             "text": "Queen Amidala",
#             "type": "Person",
#             "count": 10
#           },
#           {
#             "relevance": 0.515825,
#             "sentiment": {
#               "label": "negative",
#               "score": -0.410814
#             },
#             "text": "Obi-Wan Kenobi",
#             "type": "Person",
#             "count": 7
#           },
#           {
#             "relevance": 0.464944,
#             "sentiment": {
#               "label": "negative",
#               "score": -0.599402
#             },
#             "count": 4,
#             "disambiguation": {
#               "name": "Jedi Council",
#               "dbpedia_resource": "http://dbpedia.org/resource/Jedi_Council",
#               "subtype": []
#             },
#             "text": "Jedi Council",
#             "type": "Organization"
#           },
#           {
#             "relevance": 0.348658,
#             "sentiment": {
#               "label": "negative",
#               "score": -0.432135
#             },
#             "text": "Trade Federation",
#             "type": "Organization",
#             "count": 4
#           },
#           {
#             "relevance": 0.320867,
#             "sentiment": {
#               "label": "negative",
#               "score": -0.161194
#             },
#             "text": "droid army",
#             "type": "Organization",
#             "count": 2
#           },
#           {
#             "relevance": 0.313557,
#             "sentiment": {
#               "label": "negative",
#               "score": -0.281704
#             },
#             "count": 1,
#             "disambiguation": {
#               "subtype": [
#                 "Country"
#               ]
#             },
#             "text": "Naboo",
#             "type": "Location"
#           },
#           {
#             "relevance": 0.27729,
#             "sentiment": {
#               "label": "negative",
#               "score": -0.655772
#             },
#             "text": "Chancellor Valorum",
#             "type": "Person",
#             "count": 2
#           },
#           {
#             "relevance": 0.271629,
#             "sentiment": {
#               "label": "neutral",
#               "score": 0
#             },
#             "text": "Darth Sidious",
#             "type": "Person",
#             "count": 2
#           },
#           {
#             "relevance": 0.261733,
#             "sentiment": {
#               "label": "neutral",
#               "score": 0
#             },
#             "text": "Darth Maul",
#             "type": "Person",
#             "count": 2
#           },
#           {
#             "relevance": 0.250213,
#             "sentiment": {
#               "label": "neutral",
#               "score": 0
#             },
#             "count": 4,
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ]
#             },
#             "text": "Gungans",
#             "type": "Location"
#           },
#           {
#             "relevance": 0.240604,
#             "sentiment": {
#               "label": "negative",
#               "score": -0.256148
#             },
#             "text": "Federation Viceroy Nute Gunray",
#             "type": "Company",
#             "count": 1
#           },
#           {
#             "relevance": 0.22805,
#             "sentiment": {
#               "label": "negative",
#               "score": -0.37784
#             },
#             "count": 2,
#             "disambiguation": {
#               "name": "Galactic Republic",
#               "dbpedia_resource": "http://dbpedia.org/resource/Galactic_Republic",
#               "subtype": []
#             },
#             "text": "Galactic Senate",
#             "type": "Organization"
#           },
#           {
#             "relevance": 0.227372,
#             "sentiment": {
#               "label": "negative",
#               "score": -0.453763
#             },
#             "text": "Senator Palpatine",
#             "type": "Person",
#             "count": 2
#           },
#           {
#             "relevance": 0.220097,
#             "sentiment": {
#               "label": "neutral",
#               "score": 0
#             },
#             "text": "Padm\u00e9",
#             "type": "Person",
#             "count": 4
#           },
#           {
#             "relevance": 0.212896,
#             "sentiment": {
#               "label": "negative",
#               "score": -0.619935
#             },
#             "text": "Watto",
#             "type": "Person",
#             "count": 2
#           },
#           {
#             "relevance": 0.212202,
#             "sentiment": {
#               "label": "negative",
#               "score": -0.650413
#             },
#             "count": 1,
#             "disambiguation": {
#               "name": "United Federation of Planets",
#               "dbpedia_resource": "http://dbpedia.org/resource/United_Federation_of_Planets",
#               "subtype": []
#             },
#             "text": "Federation",
#             "type": "Organization"
#           },
#           {
#             "relevance": 0.199884,
#             "sentiment": {
#               "label": "neutral",
#               "score": 0
#             },
#             "text": "Gunray",
#             "type": "Person",
#             "count": 2
#           },
#           {
#             "relevance": 0.199225,
#             "sentiment": {
#               "label": "negative",
#               "score": -0.650413
#             },
#             "count": 2,
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ]
#             },
#             "text": "Theed",
#             "type": "Location"
#           },
#           {
#             "relevance": 0.189099,
#             "sentiment": {
#               "label": "negative",
#               "score": -0.650413
#             },
#             "text": "Chancellor",
#             "type": "JobTitle",
#             "count": 1
#           },
#           {
#             "relevance": 0.184417,
#             "sentiment": {
#               "label": "positive",
#               "score": 0.317426
#             },
#             "text": "Boss Nass",
#             "type": "Person",
#             "count": 1
#           },
#           {
#             "relevance": 0.177893,
#             "sentiment": {
#               "label": "negative",
#               "score": -0.42344
#             },
#             "text": "chancellor",
#             "type": "JobTitle",
#             "count": 1
#           },
#           {
#             "relevance": 0.175517,
#             "sentiment": {
#               "label": "negative",
#               "score": -0.470016
#             },
#             "text": "Mos Espa",
#             "type": "Company",
#             "count": 1
#           },
#           {
#             "relevance": 0.16459,
#             "sentiment": {
#               "label": "positive",
#               "score": 0.759186
#             },
#             "text": "Force",
#             "type": "Organization",
#             "count": 2
#           },
#           {
#             "relevance": 0.164269,
#             "sentiment": {
#               "label": "negative",
#               "score": -0.619935
#             },
#             "text": "Shmi",
#             "type": "Person",
#             "count": 1
#           },
#           {
#             "relevance": 0.156128,
#             "sentiment": {
#               "label": "negative",
#               "score": -0.15377
#             },
#             "text": "engineer",
#             "type": "JobTitle",
#             "count": 1
#           },
#           {
#             "relevance": 0.155488,
#             "sentiment": {
#               "label": "negative",
#               "score": -0.42344
#             },
#             "count": 1,
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ]
#             },
#             "text": "Valorum",
#             "type": "Location"
#           },
#           {
#             "relevance": 0.152477,
#             "sentiment": {
#               "label": "neutral",
#               "score": 0
#             },
#             "count": 1,
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ]
#             },
#             "text": "Podrace",
#             "type": "Location"
#           },
#           {
#             "relevance": 0.14036,
#             "sentiment": {
#               "label": "neutral",
#               "score": 0
#             },
#             "text": "nine-year",
#             "type": "Quantity",
#             "count": 1
#           },
#           {
#             "relevance": 0.14036,
#             "sentiment": {
#               "label": "neutral",
#               "score": 0
#             },
#             "text": "one",
#             "type": "Quantity",
#             "count": 1
#           }
#         ],
#         "categories": [
#           {
#             "label": "/law, govt and politics/armed forces/army",
#             "score": 0.556667
#           },
#           {
#             "label": "/art and entertainment/movies and tv/movies",
#             "score": 0.479738
#           },
#           {
#             "label": "/society/unrest and war",
#             "score": 0.139498
#           }
#         ],
#         "concepts": [
#           {
#             "relevance": 0.956316,
#             "text": "Star Wars Episode I: The Phantom Menace",
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_I:_The_Phantom_Menace"
#           },
#           {
#             "relevance": 0.86028,
#             "text": "Palpatine",
#             "dbpedia_resource": "http://dbpedia.org/resource/Palpatine"
#           },
#           {
#             "relevance": 0.81258,
#             "text": "Obi-Wan Kenobi",
#             "dbpedia_resource": "http://dbpedia.org/resource/Obi-Wan_Kenobi"
#           },
#           {
#             "relevance": 0.732788,
#             "text": "Star Wars Episode II: Attack of the Clones",
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_II:_Attack_of_the_Clones"
#           },
#           {
#             "relevance": 0.729104,
#             "text": "Qui-Gon Jinn",
#             "dbpedia_resource": "http://dbpedia.org/resource/Qui-Gon_Jinn"
#           },
#           {
#             "relevance": 0.728117,
#             "text": "Anakin Skywalker",
#             "dbpedia_resource": "http://dbpedia.org/resource/Anakin_Skywalker"
#           },
#           {
#             "relevance": 0.720274,
#             "text": "Jedi",
#             "dbpedia_resource": "http://dbpedia.org/resource/Jedi"
#           },
#           {
#             "relevance": 0.639321,
#             "text": "Sith",
#             "dbpedia_resource": "http://dbpedia.org/resource/Sith"
#           }
#         ],
#         "relations": [
#           {
#             "arguments": [
#               {
#                 "entities": [
#                   {
#                     "text": "I",
#                     "type": "Person"
#                   }
#                 ],
#                 "text": "I",
#                 "location": [
#                   19,
#                   20
#                 ]
#               },
#               {
#                 "entities": [
#                   {
#                     "text": "The Phantom Menace",
#                     "type": "TitleWork"
#                   }
#                 ],
#                 "text": "The Phantom Menace",
#                 "location": [
#                   23,
#                   41
#                 ]
#               }
#             ],
#             "type": "authorOf",
#             "sentence": "Star Wars: Episode I - The Phantom Menace",
#             "score": 0.532908
#           },
#           {
#             "arguments": [
#               {
#                 "entities": [
#                   {
#                     "text": "I",
#                     "type": "Person"
#                   }
#                 ],
#                 "text": "I",
#                 "location": [
#                   62,
#                   63
#                 ]
#               },
#               {
#                 "entities": [
#                   {
#                     "text": "The Phantom Menace",
#                     "type": "TitleWork"
#                   }
#                 ],
#                 "text": "The Phantom Menace",
#                 "location": [
#                   66,
#                   84
#                 ]
#               }
#             ],
#             "type": "authorOf",
#             "sentence": "Star Wars: Episode I - The Phantom Menace",
#             "score": 0.532908
#           },
#           {
#             "arguments": [
#               {
#                 "entities": [
#                   {
#                     "text": "Boss Nass",
#                     "type": "Person"
#                   }
#                 ],
#                 "text": "leader",
#                 "location": [
#                   778,
#                   784
#                 ]
#               },
#               {
#                 "entities": [
#                   {
#                     "text": "Gungan",
#                     "type": "GeopoliticalEntity"
#                   }
#                 ],
#                 "text": "Gungan",
#                 "location": [
#                   771,
#                   777
#                 ]
#               }
#             ],
#             "type": "residesIn",
#             "sentence": "The Jedi unsuccessfully try to persuade the Gungan leader, Boss Nass, into helping the people of Naboo, though they are able to obtain transportation to Theed, the capital city on the surface.",
#             "score": 0.866138
#           },
#           {
#             "arguments": [
#               {
#                 "entities": [
#                   {
#                     "text": "people",
#                     "type": "Person"
#                   }
#                 ],
#                 "text": "people",
#                 "location": [
#                   814,
#                   820
#                 ]
#               },
#               {
#                 "entities": [
#                   {
#                     "text": "Naboo",
#                     "type": "GeopoliticalEntity"
#                   }
#                 ],
#                 "text": "Naboo",
#                 "location": [
#                   824,
#                   829
#                 ]
#               }
#             ],
#             "type": "residesIn",
#             "sentence": "The Jedi unsuccessfully try to persuade the Gungan leader, Boss Nass, into helping the people of Naboo, though they are able to obtain transportation to Theed, the capital city on the surface.",
#             "score": 0.865092
#           },
#           {
#             "arguments": [
#               {
#                 "entities": [
#                   {
#                     "text": "people",
#                     "type": "Person"
#                   }
#                 ],
#                 "text": "people",
#                 "location": [
#                   970,
#                   976
#                 ]
#               },
#               {
#                 "entities": [
#                   {
#                     "text": "Naboo",
#                     "type": "GeopoliticalEntity"
#                   }
#                 ],
#                 "text": "Naboo",
#                 "location": [
#                   964,
#                   969
#                 ]
#               }
#             ],
#             "type": "residesIn",
#             "sentence": "They rescue Queen Amidala, the ruler of the Naboo people, and escape the planet on her royal starship, which is damaged as they pass the Federation blockade.",
#             "score": 0.426201
#           },
#           {
#             "arguments": [
#               {
#                 "entities": [
#                   {
#                     "text": "Queen Amidala",
#                     "type": "Organization"
#                   }
#                 ],
#                 "text": "Amidala",
#                 "location": [
#                   1079,
#                   1086
#                 ]
#               },
#               {
#                 "entities": [
#                   {
#                     "text": "ship",
#                     "type": "Vehicle"
#                   }
#                 ],
#                 "text": "ship",
#                 "location": [
#                   1089,
#                   1093
#                 ]
#               }
#             ],
#             "type": "ownerOf",
#             "sentence": "Amidala's ship is unable to sustain its hyperdrive and lands for repairs on the desert planet Tatooine.",
#             "score": 0.413548
#           },
#           {
#             "arguments": [
#               {
#                 "entities": [
#                   {
#                     "text": "desert",
#                     "type": "GeographicFeature"
#                   }
#                 ],
#                 "text": "desert",
#                 "location": [
#                   1159,
#                   1165
#                 ]
#               },
#               {
#                 "entities": [
#                   {
#                     "text": "Naboo",
#                     "type": "GeopoliticalEntity"
#                   }
#                 ],
#                 "text": "planet",
#                 "location": [
#                   1166,
#                   1172
#                 ]
#               }
#             ],
#             "type": "locatedAt",
#             "sentence": "Amidala's ship is unable to sustain its hyperdrive and lands for repairs on the desert planet Tatooine.",
#             "score": 0.671515
#           },
#           {
#             "arguments": [
#               {
#                 "entities": [
#                   {
#                     "text": "Tatooine",
#                     "type": "Person"
#                   }
#                 ],
#                 "text": "Tatooine",
#                 "location": [
#                   1173,
#                   1181
#                 ]
#               },
#               {
#                 "entities": [
#                   {
#                     "text": "Naboo",
#                     "type": "GeopoliticalEntity"
#                   }
#                 ],
#                 "text": "planet",
#                 "location": [
#                   1166,
#                   1172
#                 ]
#               }
#             ],
#             "type": "residesIn",
#             "sentence": "Amidala's ship is unable to sustain its hyperdrive and lands for repairs on the desert planet Tatooine.",
#             "score": 0.296276
#           },
#           {
#             "arguments": [
#               {
#                 "entities": [
#                   {
#                     "text": "Mos Espa",
#                     "type": "Person"
#                   }
#                 ],
#                 "text": "Mos Espa",
#                 "location": [
#                   1298,
#                   1306
#                 ]
#               },
#               {
#                 "entities": [
#                   {
#                     "text": "settlement",
#                     "type": "EventLegal"
#                   }
#                 ],
#                 "text": "settlement",
#                 "location": [
#                   1284,
#                   1294
#                 ]
#               }
#             ],
#             "type": "affectedBy",
#             "sentence": "Qui-Gon, Jar Jar, astromech droid R2-D2, and Amidala (in disguise as the handmaiden Padm\u00e9) visit the settlement of Mos Espa to buy new parts at a junk shop.",
#             "score": 0.712734
#           },
#           {
#             "arguments": [
#               {
#                 "entities": [
#                   {
#                     "text": "Shmi",
#                     "type": "Person"
#                   }
#                 ],
#                 "text": "mother",
#                 "location": [
#                   1797,
#                   1803
#                 ]
#               },
#               {
#                 "entities": [
#                   {
#                     "text": "Jedi Knight Qui-Gon Jinn",
#                     "type": "Person"
#                   }
#                 ],
#                 "text": "his",
#                 "location": [
#                   1793,
#                   1796
#                 ]
#               }
#             ],
#             "type": "parentOf",
#             "sentence": "Anakin joins the group to be trained as a Jedi, leaving his mother Shmi behind.",
#             "score": 0.627572
#           },
#           {
#             "arguments": [
#               {
#                 "entities": [
#                   {
#                     "text": "Darth Sidious",
#                     "type": "Person"
#                   }
#                 ],
#                 "text": "Darth Sidious",
#                 "location": [
#                   1884,
#                   1897
#                 ]
#               },
#               {
#                 "entities": [
#                   {
#                     "text": "Darth Maul",
#                     "type": "Person"
#                   }
#                 ],
#                 "text": "apprentice",
#                 "location": [
#                   1900,
#                   1910
#                 ]
#               }
#             ],
#             "type": "clientOf",
#             "sentence": "En route to their starship, Qui-Gon briefly duels with Darth Maul, Darth Sidious's apprentice, who was sent to capture Amidala.",
#             "score": 0.390007
#           },
#           {
#             "arguments": [
#               {
#                 "entities": [
#                   {
#                     "text": "Coruscant",
#                     "type": "GeopoliticalEntity"
#                   }
#                 ],
#                 "text": "planet",
#                 "location": [
#                   2106,
#                   2112
#                 ]
#               },
#               {
#                 "entities": [
#                   {
#                     "text": "Naboo",
#                     "type": "GeopoliticalEntity"
#                   }
#                 ],
#                 "text": "capital",
#                 "location": [
#                   2098,
#                   2105
#                 ]
#               }
#             ],
#             "type": "capitalOf",
#             "sentence": "Qui-Gon and Obi-Wan escort Amidala to the Republic capital planet of Coruscant so that she can plead her people's case to Chancellor Valorum and the Galactic Senate.",
#             "score": 0.829459
#           },
#           {
#             "arguments": [
#               {
#                 "entities": [
#                   {
#                     "text": "Valorum",
#                     "type": "Person"
#                   }
#                 ],
#                 "text": "leader",
#                 "location": [
#                   114,
#                   120
#                 ]
#               },
#               {
#                 "entities": [
#                   {
#                     "text": "Galactic Republic",
#                     "type": "Organization"
#                   }
#                 ],
#                 "text": "Galactic Republic",
#                 "location": [
#                   128,
#                   145
#                 ]
#               }
#             ],
#             "type": "employedBy",
#             "sentence": "Supreme Chancellor Valorum, leader of the Galactic Republic, dispatches Jedi Knight Qui-Gon Jinn and his apprentice, Obi-Wan Kenobi, to negotiate with the Trade Federation leadership to end a blockade of battleships around the planet Naboo.",
#             "score": 0.273952
#           },
#           {
#             "arguments": [
#               {
#                 "entities": [
#                   {
#                     "text": "Shmi",
#                     "type": "Person"
#                   }
#                 ],
#                 "text": "she",
#                 "location": [
#                   2134,
#                   2137
#                 ]
#               },
#               {
#                 "entities": [
#                   {
#                     "text": "plead",
#                     "type": "EventCommunication"
#                   }
#                 ],
#                 "text": "plead",
#                 "location": [
#                   2142,
#                   2147
#                 ]
#               }
#             ],
#             "type": "agentOf",
#             "sentence": "Qui-Gon and Obi-Wan escort Amidala to the Republic capital planet of Coruscant so that she can plead her people's case to Chancellor Valorum and the Galactic Senate.",
#             "score": 0.97835
#           },
#           {
#             "arguments": [
#               {
#                 "entities": [
#                   {
#                     "text": "Shmi",
#                     "type": "Person"
#                   }
#                 ],
#                 "text": "her",
#                 "location": [
#                   2148,
#                   2151
#                 ]
#               },
#               {
#                 "entities": [
#                   {
#                     "text": "case",
#                     "type": "EventLegal"
#                   }
#                 ],
#                 "text": "case",
#                 "location": [
#                   2161,
#                   2165
#                 ]
#               }
#             ],
#             "type": "affectedBy",
#             "sentence": "Qui-Gon and Obi-Wan escort Amidala to the Republic capital planet of Coruscant so that she can plead her people's case to Chancellor Valorum and the Galactic Senate.",
#             "score": 0.517291
#           },
#           {
#             "arguments": [
#               {
#                 "entities": [
#                   {
#                     "text": "Qui-Gon senses",
#                     "type": "Person"
#                   }
#                 ],
#                 "text": "Qui-Gon",
#                 "location": [
#                   2213,
#                   2220
#                 ]
#               },
#               {
#                 "entities": [
#                   {
#                     "text": "asks",
#                     "type": "EventCommunication"
#                   }
#                 ],
#                 "text": "asks",
#                 "location": [
#                   2221,
#                   2225
#                 ]
#               }
#             ],
#             "type": "agentOf",
#             "sentence": "Qui-Gon asks the Jedi Council for permission to train Anakin as a Jedi, but the Council refuses, concerned that Anakin is vulnerable to the dark side.",
#             "score": 0.996641
#           },
#           {
#             "arguments": [
#               {
#                 "entities": [
#                   {
#                     "text": "Qui-Gon senses",
#                     "type": "Person"
#                   }
#                 ],
#                 "text": "Qui-Gon",
#                 "location": [
#                   3601,
#                   3608
#                 ]
#               },
#               {
#                 "entities": [
#                   {
#                     "text": "asks",
#                     "type": "EventCommunication"
#                   }
#                 ],
#                 "text": "asks",
#                 "location": [
#                   3609,
#                   3613
#                 ]
#               }
#             ],
#             "type": "agentOf",
#             "sentence": "As he dies, Qui-Gon asks Obi-Wan to train Anakin.",
#             "score": 0.997279
#           },
#           {
#             "arguments": [
#               {
#                 "entities": [
#                   {
#                     "disambiguation": {
#                       "subtype": [
#                         "Multigov"
#                       ]
#                     },
#                     "text": "Council",
#                     "type": "Organization"
#                   }
#                 ],
#                 "text": "Council",
#                 "location": [
#                   2235,
#                   2242
#                 ]
#               },
#               {
#                 "entities": [
#                   {
#                     "text": "asks",
#                     "type": "EventCommunication"
#                   }
#                 ],
#                 "text": "asks",
#                 "location": [
#                   2221,
#                   2225
#                 ]
#               }
#             ],
#             "type": "affectedBy",
#             "sentence": "Qui-Gon asks the Jedi Council for permission to train Anakin as a Jedi, but the Council refuses, concerned that Anakin is vulnerable to the dark side.",
#             "score": 0.588586
#           },
#           {
#             "arguments": [
#               {
#                 "entities": [
#                   {
#                     "text": "Jedi Knight Qui-Gon Jinn",
#                     "type": "Person"
#                   }
#                 ],
#                 "text": "Jedi",
#                 "location": [
#                   2230,
#                   2234
#                 ]
#               },
#               {
#                 "entities": [
#                   {
#                     "disambiguation": {
#                       "subtype": [
#                         "Multigov"
#                       ]
#                     },
#                     "text": "Council",
#                     "type": "Organization"
#                   }
#                 ],
#                 "text": "Council",
#                 "location": [
#                   2235,
#                   2242
#                 ]
#               }
#             ],
#             "type": "managerOf",
#             "sentence": "Qui-Gon asks the Jedi Council for permission to train Anakin as a Jedi, but the Council refuses, concerned that Anakin is vulnerable to the dark side.",
#             "score": 0.748284
#           },
#           {
#             "arguments": [
#               {
#                 "entities": [
#                   {
#                     "disambiguation": {
#                       "subtype": [
#                         "Multigov"
#                       ]
#                     },
#                     "text": "Council",
#                     "type": "Organization"
#                   }
#                 ],
#                 "text": "Council",
#                 "location": [
#                   2293,
#                   2300
#                 ]
#               },
#               {
#                 "entities": [
#                   {
#                     "text": "refuses",
#                     "type": "EventCommunication"
#                   }
#                 ],
#                 "text": "refuses",
#                 "location": [
#                   2301,
#                   2308
#                 ]
#               }
#             ],
#             "type": "agentOf",
#             "sentence": "Qui-Gon asks the Jedi Council for permission to train Anakin as a Jedi, but the Council refuses, concerned that Anakin is vulnerable to the dark side.",
#             "score": 0.991257
#           },
#           {
#             "arguments": [
#               {
#                 "entities": [
#                   {
#                     "text": "Palpatine persuades Amidala",
#                     "type": "Person"
#                   }
#                 ],
#                 "text": "Senator",
#                 "location": [
#                   2432,
#                   2439
#                 ]
#               },
#               {
#                 "entities": [
#                   {
#                     "disambiguation": {
#                       "subtype": [
#                         "Commercial"
#                       ]
#                     },
#                     "text": "Naboo",
#                     "type": "Organization"
#                   }
#                 ],
#                 "text": "Naboo",
#                 "location": [
#                   2424,
#                   2429
#                 ]
#               }
#             ],
#             "type": "employedBy",
#             "sentence": "Meanwhile, Naboo's Senator Palpatine persuades Amidala to make a vote of no confidence in Valorum to elect a more capable chancellor to resolve the crisis on Naboo.",
#             "score": 0.657607
#           },
#           {
#             "arguments": [
#               {
#                 "entities": [
#                   {
#                     "text": "Shmi",
#                     "type": "Person"
#                   }
#                 ],
#                 "text": "she",
#                 "location": [
#                   2585,
#                   2588
#                 ]
#               },
#               {
#                 "entities": [
#                   {
#                     "text": "vote",
#                     "type": "EventElection"
#                   }
#                 ],
#                 "text": "vote",
#                 "location": [
#                   2622,
#                   2626
#                 ]
#               }
#             ],
#             "type": "affectedBy",
#             "sentence": "Though she is successful in pushing for the vote, Amidala grows frustrated with the corruption in the Senate and decides to return to Naboo.",
#             "score": 0.387926
#           },
#           {
#             "arguments": [
#               {
#                 "entities": [
#                   {
#                     "text": "Amidala grows",
#                     "type": "Person"
#                   }
#                 ],
#                 "text": "Amidala grows",
#                 "location": [
#                   2628,
#                   2641
#                 ]
#               },
#               {
#                 "entities": [
#                   {
#                     "text": "Galactic Senate",
#                     "type": "Organization"
#                   }
#                 ],
#                 "text": "Senate",
#                 "location": [
#                   2680,
#                   2686
#                 ]
#               }
#             ],
#             "type": "employedBy",
#             "sentence": "Though she is successful in pushing for the vote, Amidala grows frustrated with the corruption in the Senate and decides to return to Naboo.",
#             "score": 0.366213
#           },
#           {
#             "arguments": [
#               {
#                 "entities": [
#                   {
#                     "text": "Amidala grows",
#                     "type": "Person"
#                   }
#                 ],
#                 "text": "Amidala grows",
#                 "location": [
#                   2628,
#                   2641
#                 ]
#               },
#               {
#                 "entities": [
#                   {
#                     "text": "Naboo",
#                     "type": "GeopoliticalEntity"
#                   }
#                 ],
#                 "text": "Naboo",
#                 "location": [
#                   2712,
#                   2717
#                 ]
#               }
#             ],
#             "type": "residesIn",
#             "sentence": "Though she is successful in pushing for the vote, Amidala grows frustrated with the corruption in the Senate and decides to return to Naboo.",
#             "score": 0.457147
#           },
#           {
#             "arguments": [
#               {
# ...
#                     "text": "Finn encounters Rey",
#                     "type": "Person"
#                   }
#                 ],
#                 "text": "Finn",
#                 "location": [
#                   3233,
#                   3237
#                 ]
#               },
#               {
#                 "entities": [
#                   {
#                     "text": "facility",
#                     "type": "Facility"
#                   }
#                 ],
#                 "text": "facility",
#                 "location": [
#                   3253,
#                   3261
#                 ]
#               }
#             ],
#             "type": "locatedAt",
#             "sentence": "Using the Falcon, Han, Chewbacca, and Finn infiltrate the facility, find Rey, and plant explosives.",
#             "score": 0.702476
#           },
#           {
#             "arguments": [
#               {
#                 "entities": [
#                   {
#                     "text": "Han Solo",
#                     "type": "Person"
#                   }
#                 ],
#                 "text": "Han",
#                 "location": [
#                   3295,
#                   3298
#                 ]
#               },
#               {
#                 "entities": [
#                   {
#                     "text": "confronts",
#                     "type": "EventCommunication"
#                   }
#                 ],
#                 "text": "confronts",
#                 "location": [
#                   3299,
#                   3308
#                 ]
#               }
#             ],
#             "type": "agentOf",
#             "sentence": "Han confronts Ren, calling him by his birth name, Ben, and implores him to abandon the dark side.",
#             "score": 0.998004
#           },
#           {
#             "arguments": [
#               {
#                 "entities": [
#                   {
#                     "text": "Kylo Ren",
#                     "type": "Person"
#                   }
#                 ],
#                 "text": "Ren",
#                 "location": [
#                   3309,
#                   3312
#                 ]
#               },
#               {
#                 "entities": [
#                   {
#                     "text": "confronts",
#                     "type": "EventCommunication"
#                   }
#                 ],
#                 "text": "confronts",
#                 "location": [
#                   3299,
#                   3308
#                 ]
#               }
#             ],
#             "type": "affectedBy",
#             "sentence": "Han confronts Ren, calling him by his birth name, Ben, and implores him to abandon the dark side.",
#             "score": 0.918518
#           },
#           {
#             "arguments": [
#               {
#                 "entities": [
#                   {
#                     "text": "Finn encounters Rey",
#                     "type": "Person"
#                   }
#                 ],
#                 "text": "Rey",
#                 "location": [
#                   690,
#                   693
#                 ]
#               },
#               {
#                 "entities": [
#                   {
#                     "text": "settlement",
#                     "type": "EventLegal"
#                   }
#                 ],
#                 "text": "settlement",
#                 "location": [
#                   710,
#                   720
#                 ]
#               }
#             ],
#             "type": "affectedBy",
#             "sentence": "Poe's droid, BB-8, escapes with the map and encounters a scavenger named Rey near a junkyard settlement.",
#             "score": 0.637382
#           },
#           {
#             "arguments": [
#               {
#                 "entities": [
#                   {
#                     "text": "Han Solo",
#                     "type": "Person"
#                   }
#                 ],
#                 "text": "him",
#                 "location": [
#                   3322,
#                   3325
#                 ]
#               },
#               {
#                 "entities": [
#                   {
#                     "text": "calling",
#                     "type": "EventCommunication"
#                   }
#                 ],
#                 "text": "calling",
#                 "location": [
#                   3314,
#                   3321
#                 ]
#               }
#             ],
#             "type": "affectedBy",
#             "sentence": "Han confronts Ren, calling him by his birth name, Ben, and implores him to abandon the dark side.",
#             "score": 0.751323
#           },
#           {
#             "arguments": [
#               {
#                 "entities": [
#                   {
#                     "text": "Kylo Ren",
#                     "type": "Person"
#                   }
#                 ],
#                 "text": "Ren",
#                 "location": [
#                   3393,
#                   3396
#                 ]
#               },
#               {
#                 "entities": [
#                   {
#                     "text": "refuses",
#                     "type": "EventCommunication"
#                   }
#                 ],
#                 "text": "refuses",
#                 "location": [
#                   3397,
#                   3404
#                 ]
#               }
#             ],
#             "type": "agentOf",
#             "sentence": "Ren refuses and kills Han, enraging Chewbacca, who fires and hits Ren.",
#             "score": 0.99654
#           },
#           {
#             "arguments": [
#               {
#                 "entities": [
#                   {
#                     "text": "Chewbacca",
#                     "type": "Person"
#                   }
#                 ],
#                 "text": "who",
#                 "location": [
#                   3440,
#                   3443
#                 ]
#               },
#               {
#                 "entities": [
#                   {
#                     "text": "fires",
#                     "type": "NaturalDisaster"
#                   }
#                 ],
#                 "text": "fires",
#                 "location": [
#                   3444,
#                   3449
#                 ]
#               }
#             ],
#             "type": "agentOf",
#             "sentence": "Ren refuses and kills Han, enraging Chewbacca, who fires and hits Ren.",
#             "score": 0.384637
#           },
#           {
#             "arguments": [
#               {
#                 "entities": [
#                   {
#                     "text": "Finn encounters Rey",
#                     "type": "Person"
#                   }
#                 ],
#                 "text": "Rey",
#                 "location": [
#                   3686,
#                   3689
#                 ]
#               },
#               {
#                 "entities": [
#                   {
#                     "text": "Force Awakens",
#                     "type": "Organization"
#                   }
#                 ],
#                 "text": "Force",
#                 "location": [
#                   3724,
#                   3729
#                 ]
#               }
#             ],
#             "type": "employedBy",
#             "sentence": "Rey takes the lightsaber and uses the Force to defeat Ren, before they are separated by a fissure as the planet begins to disintegrate and implode.",
#             "score": 0.365008
#           },
#           {
#             "arguments": [
#               {
#                 "entities": [
#                   {
#                     "text": "Finn encounters Rey",
#                     "type": "Person"
#                   }
#                 ],
#                 "text": "Rey",
#                 "location": [
#                   3686,
#                   3689
#                 ]
#               },
#               {
#                 "entities": [
#                   {
#                     "text": "they",
#                     "type": "Person"
#                   }
#                 ],
#                 "text": "they",
#                 "location": [
#                   3752,
#                   3756
#                 ]
#               }
#             ],
#             "type": "partOfMany",
#             "sentence": "Rey takes the lightsaber and uses the Force to defeat Ren, before they are separated by a fissure as the planet begins to disintegrate and implode.",
#             "score": 0.925867
#           },
#           {
#             "arguments": [
#               {
#                 "entities": [
#                   {
#                     "text": "Kylo Ren",
#                     "type": "Person"
#                   }
#                 ],
#                 "text": "Ren",
#                 "location": [
#                   3740,
#                   3743
#                 ]
#               },
#               {
#                 "entities": [
#                   {
#                     "text": "they",
#                     "type": "Person"
#                   }
#                 ],
#                 "text": "they",
#                 "location": [
#                   3752,
#                   3756
#                 ]
#               }
#             ],
#             "type": "partOfMany",
#             "sentence": "Rey takes the lightsaber and uses the Force to defeat Ren, before they are separated by a fissure as the planet begins to disintegrate and implode.",
#             "score": 0.848147
#           },
#           {
#             "arguments": [
#               {
#                 "entities": [
#                   {
#                     "text": "they",
#                     "type": "Person"
#                   }
#                 ],
#                 "text": "they",
#                 "location": [
#                   3752,
#                   3756
#                 ]
#               },
#               {
#                 "entities": [
#                   {
#                     "text": "village",
#                     "type": "GeopoliticalEntity"
#                   }
#                 ],
#                 "text": "planet",
#                 "location": [
#                   3791,
#                   3797
#                 ]
#               }
#             ],
#             "type": "locatedAt",
#             "sentence": "Rey takes the lightsaber and uses the Force to defeat Ren, before they are separated by a fissure as the planet begins to disintegrate and implode.",
#             "score": 0.43266
#           },
#           {
#             "arguments": [
#               {
#                 "entities": [
#                   {
#                     "text": "Finn encounters Rey",
#                     "type": "Person"
#                   }
#                 ],
#                 "text": "Finn",
#                 "location": [
#                   3915,
#                   3919
#                 ]
#               },
#               {
#                 "entities": [
#                   {
#                     "text": "Millennium Falcon",
#                     "type": "Organization"
#                   }
#                 ],
#                 "text": "Falcon",
#                 "location": [
#                   3927,
#                   3933
#                 ]
#               }
#             ],
#             "type": "employedBy",
#             "sentence": "Rey and Chewbacca escape with Finn in the Falcon.",
#             "score": 0.876121
#           },
#           {
#             "arguments": [
#               {
#                 "entities": [
#                   {
#                     "text": "village",
#                     "type": "GeopoliticalEntity"
#                   }
#                 ],
#                 "text": "planet",
#                 "location": [
#                   4101,
#                   4107
#                 ]
#               },
#               {
#                 "entities": [
#                   {
#                     "text": "oceanic",
#                     "type": "GeographicFeature"
#                   }
#                 ],
#                 "text": "oceanic",
#                 "location": [
#                   4093,
#                   4100
#                 ]
#               }
#             ],
#             "type": "locatedAt",
#             "sentence": "R2-D2 awakens and reveals the rest of the map, which Rey follows to the oceanic planet Ahch-To.",
#             "score": 0.587665
#           },
#           {
#             "arguments": [
#               {
#                 "entities": [
#                   {
#                     "text": "Stormtrooper",
#                     "type": "Person"
#                   }
#                 ],
#                 "text": "Stormtrooper",
#                 "location": [
#                   776,
#                   788
#                 ]
#               },
#               {
#                 "entities": [
#                   {
#                     "text": "their",
#                     "type": "Person"
#                   }
#                 ],
#                 "text": "they",
#                 "location": [
#                   832,
#                   836
#                 ]
#               }
#             ],
#             "type": "partOfMany",
#             "sentence": "Stormtrooper FN-2187, unwilling to kill, frees Poe, and they escape in a stolen TIE fighter; Poe dubs FN-2187 \"Finn\".",
#             "score": 0.950682
#           },
#           {
#             "arguments": [
#               {
#                 "entities": [
#                   {
#                     "text": "Ren captures Rey",
#                     "type": "Person"
#                   }
#                 ],
#                 "text": "Poe",
#                 "location": [
#                   823,
#                   826
#                 ]
#               },
#               {
#                 "entities": [
#                   {
#                     "text": "their",
#                     "type": "Person"
#                   }
#                 ],
#                 "text": "they",
#                 "location": [
#                   832,
#                   836
#                 ]
#               }
#             ],
#             "type": "partOfMany",
#             "sentence": "Stormtrooper FN-2187, unwilling to kill, frees Poe, and they escape in a stolen TIE fighter; Poe dubs FN-2187 \"Finn\".",
#             "score": 0.739845
#           },
#           {
#             "arguments": [
#               {
#                 "entities": [
#                   {
#                     "text": "Poe Dameron meets",
#                     "type": "Person"
#                   }
#                 ],
#                 "text": "Poe",
#                 "location": [
#                   938,
#                   941
#                 ]
#               },
#               {
#                 "entities": [
#                   {
#                     "text": "crash",
#                     "type": "NaturalDisaster"
#                   }
#                 ],
#                 "text": "crash",
#                 "location": [
#                   981,
#                   986
#                 ]
#               }
#             ],
#             "type": "affectedBy",
#             "sentence": "They crash on Jakku, and Finn survives, but Poe is believed to have been killed in the crash.",
#             "score": 0.353232
#           },
#           {
#             "arguments": [
#               {
#                 "entities": [
#                   {
#                     "text": "Millennium Falcon",
#                     "type": "Organization"
#                   }
#                 ],
#                 "text": "Millennium Falcon",
#                 "location": [
#                   1120,
#                   1137
#                 ]
#               },
#               {
#                 "entities": [
#                   {
#                     "text": "village",
#                     "type": "GeopoliticalEntity"
#                   }
#                 ],
#                 "text": "planet",
#                 "location": [
#                   1106,
#                   1112
#                 ]
#               }
#             ],
#             "type": "basedIn",
#             "sentence": "Finn, Rey, and BB-8 flee the planet in the Millennium Falcon, which they steal from a junkyard.",
#             "score": 0.375903
#           }
#         ]
#       },
#       "extracted_metadata": {
#         "file_type": "html",
#         "title": "Star Wars: Episode VII - The Force Awakens",
#         "sha1": "4d233f084e1e679ed1033b2f4114b2fcfbb05c02",
#         "filename": "Episode-VII_The-Force-Awakens.html"
#       }
#     }
#   ],
#   "matching_results": 8
# }

# %% [markdown]
# Change the above query and see what results you get! Try to find one that returns relevant results, and keep that (along with the output) for review.
#
# > See [Query building reference](https://www.ibm.com/watson/developercloud/doc/discovery/query-reference.html) for descriptions of all possible parameters, operators and aggregations. You can also choose to build the query using the web interface (click the "Story Chunks" collection to query it), and then reproduce the query here.
#
# Then answer the questions below:
#
# **Q**: What query did you try? Express it in plain words below.
#
# **A**: Looked fro Jar Jar Binks
#
#
# **Q**: What answer did you get back from Watson? You only need to mention the relevant snippet of text fro mthe paragraph(s) returned.
#
# **A**: Jar Jar Binks is emploted my Qui-Gon Jinn
# {
#             "arguments": [
#               {
#                 "entities": [
#                   {
#                     "text": "Jedi Knight Qui-Gon Jinn",
#                     "type": "Person"
#                   }
#                 ],
#                 "text": "Jedi",
#                 "location": [
#                   672,
#                   676
#                 ]
#               },
#               {
#                 "entities": [
#                   {
#                     "disambiguation": {
#                       "subtype": [
#                         "Commercial"
#                       ]
#                     },
#                     "text": "Jar Jar Binks",
#                     "type": "Organization"
#                   }
#                 ],
#                 "text": "Jar Jar",
#                 "location": [
#                   678,
#                   685
#                 ]
#               }
#             ],
#             "type": "employedBy",
#             "sentence": "Indebted to the Jedi, Jar Jar leads them to an underwater Gungan city.",
#             "score": 0.718865
#           }
#         ]
#       },
#       "extracted_metadata": {
#         "file_type": "html",
#         "title": "Star Wars: Episode I - The Phantom Menace",
#         "sha1": "655bb64f85a4849366a64999b9579c75b7b8d500",
#         "filename": "Episode-I_The-Phantom-Menace.html"
#       }
#     },

# %% [markdown]
# ## 3. Parse natural language questions
#
# In order to understand questions posed in natural language, we'll use another Watson service called [Conversation](https://www.ibm.com/watson/developercloud/doc/conversation/index.html). It can be used to design conversational agents or _chatbots_ that exhibit complex behavior, but for the purpose of this project, we'll only use it to parse certain kinds of queries.
#
# ### Create a Conversation service instance
#
# Just like you did for the Discovery service, create an instance of the Conversation service. Then launch the associated tool from the service dashboard.
#
# <img src="images/conversation-tooling.png" alt="Conversation service - Tool homepage" width="800" />
#
# A _workspace_ allows you to keep all the items you need for a particular application in one place, just like an _environment_ in case of the Discovery service. Create one called "Bookworm" with a suitable description, such as "I know a lot of stories. Ask me a question!"
#
# <img src="images/conversation-workspace.png" alt="Conversation service - Blank workspace" width="800" />
#
# This should open up a blank workspace, where you can add intents, define the entities you want the agent to idenitfy and structure the overall dialog.
#
# ### Add intents
#
# An _intent_ is the goal or purpose of a user's input. Create a set of intents (at least 3) that capture the different kinds of questions that you want the system to answer, e.g. _who_, _what_ and _where_. Along with each intent, add a list of user examples or _utterances_ that map to that intent.
#
# For instance, you could enter the following examples for the _where_ intent:
#
# - Where is the Jedi temple located?
# - Where was Luke born?
#
# The Conversation service recommends at least 5 examples for each intent so that Watson learns how to recognize it. These don't have to be very precise, but more examples the better.
#
# <img src="images/conversation-intents.png" alt="Conversation service - Intents listed" width="800" />
#
# Feel free to create your own intents, based on the kinds of questions you want the system to answer, e.g. "How many ...", "What are the most common ..." etc. Each intent will need to be mapped to an appropriate query.
#
# > See [**Defining intents**](https://www.ibm.com/watson/developercloud/doc/conversation/intents.html) for a helpful video and further instructions.
#
# **Q**: What intents did you add to the Conversation service instance?
#
# **A**:
# What?
# Where?
# Who?
#
#
# **Q**: Pick one of these intents, and list at least 5 examples for the intent that you entered.
#
# **A**:
# No.
#
#
# ### Add entities
#
# Once you have your intents set, let's tell the service what entities we want it to identify. One way to do this is using the tool interface, and entering them one-by-one.
#
# > Go to [**Defining entities**](https://www.ibm.com/watson/developercloud/doc/conversation/entities.html) to see how that is done.
#
# But that can be tedious! So let's refer back to the entities that the Discovery service identified, and load them in programmatically.
#
# As before, let's connect to the Conversation service first. Remember to enter your service credentials below.

# %%
# Connect to the Conversation service instance
# TODO: Enter your username and password from the Service Credentials tab in service-credentials.json
conversation_creds = helper.fetch_credentials('conversation')
conversation = watson_developer_cloud.ConversationV1(
    version='2017-02-03',
    username=conversation_creds['username'],
    password=conversation_creds['password'])

# %% [markdown]
# Fetch the workspace you just created called "Bookworm".

# %%
wrk, wrk_id = helper.fetch_object(conversation, "workspace", "Bookworm")
print(json.dumps(wrk, indent=2))
# Out:
# Found workspace: Bookworm (4c365990-ee83-4f93-a308-efc5df69149d)
# {
#   "system_settings": {
#     "human_agent_assist": {
#       "prompt": "Did you mean:"
#     },
#     "disambiguation": {
#       "none_of_the_above_prompt": "None of the above",
#       "prompt": "Did you mean:"
#     },
#     "tooling": {
#       "store_generic_responses": true
#     }
#   },
#   "updated": "2018-08-07T22:18:49.803Z",
#   "created": "2018-08-07T21:56:23.821Z",
#   "workspace_id": "4c365990-ee83-4f93-a308-efc5df69149d",
#   "status": "Available",
#   "metadata": null,
#   "name": "Bookworm",
#   "language": "en",
#   "description": "I know a lot about Star Wars",
#   "learning_opt_out": false
# }

# %% [markdown]
# Collect all the entities from the Discovery service collection.

# %%
# Get all the entities from the collection and group them by type
response = discovery.query(environment_id=env_id, collection_id=col_id,
    query_options={
        "return": "enriched_text.entities.type,enriched_text.entities.text"
    })

# Group individual entities by type ("Person", "Location", etc.)
entities_by_type = {}
for document in response["results"]:
    for entity in document["enriched_text"]["entities"]:
        if entity["type"] not in entities_by_type:
            entities_by_type[entity["type"]] = set()
        entities_by_type[entity["type"]].add(entity["text"])

# Ignore case to avoid duplicates
for entity_type in entities_by_type:
    entities_by_type[entity_type] = {
        e.lower(): e for e in entities_by_type[entity_type]
    }.values()

# Restructure for loading into Conversation workspace
entities_grouped = [{
    "entity": entity_type,
    "values": [{"value": entity} for entity in entities]}
        for entity_type, entities in entities_by_type.items()]
entities_grouped
# Out:
# [{'entity': 'GeographicFeature',
#   'values': [{'value': 'Starkiller Base'}, {'value': 'Sarlacc pit'}]},
#  {'entity': 'Facility',
#   'values': [{'value': 'Grand Moff Tarkin'},
#    {'value': 'Imperial shuttle'},
#    {'value': "Jabba's palace"},
#    {'value': 'Jedi Temple'},
#    {'value': 'Galactic Empire'}]},
#  {'entity': 'JobTitle',
#   'values': [{'value': 'engineer'},
#    {'value': 'commander'},
#    {'value': 'chancellor'},
#    {'value': 'representative'},
#    {'value': 'officer'},
#    {'value': 'Research scientist'},
#    {'value': 'developer'}]},
#  {'entity': 'Crime', 'values': [{'value': 'assault'}]},
#  {'entity': 'Company',
#   'values': [{'value': 'Cloud City'},
#    {'value': 'Falcon'},
#    {'value': 'carbonite'},
#    {'value': 'Mos Espa'},
#    {'value': 'Imperial communications'},
#    {'value': 'Federation Viceroy Nute Gunray'},
#    {'value': 'Jawa traders'},
#    {'value': 'General Hux'}]},
#  {'entity': 'Quantity',
#   'values': [{'value': 'Three decades'},
#    {'value': 'Three years'},
#    {'value': 'one'},
#    {'value': 'Ten years'},
#    {'value': 'Fifteen years'},
#    {'value': 'nine-year'}]},
#  {'entity': 'Person',
#   'values': [{'value': 'Cliegg Lars'},
#    {'value': 'Lyra'},
#    {'value': 'Bodhi Rook'},
#    {'value': 'Baze Malbus'},
#    {'value': 'Tarkin'},
#    {'value': 'Anakin Skywalker'},
#    {'value': 'Watto'},
#    {'value': 'Lando Calrissian'},
#    {'value': 'Owen'},
#    {'value': 'Darth Vader'},
#    {'value': 'Mon Mothma'},
#    {'value': 'Wookiee'},
#    {'value': 'Darth Maul'},
#    {'value': 'Gunray'},
#    {'value': 'Shmi'},
#    {'value': 'Darth Sidious'},
#    {'value': 'Senator Padmé Amidala'},
#    {'value': 'Han Solo'},
#    {'value': 'Cassian'},
#    {'value': 'Luke'},
#    {'value': 'Boss Nass'},
#    {'value': 'Kylo Ren'},
#    {'value': 'Galen Erso'},
#    {'value': 'Rey'},
#    {'value': 'Leia'},
#    {'value': 'Chirrut Îmwe'},
#    {'value': 'Padmé'},
#    {'value': 'Beru Lars'},
#    {'value': 'Yoda'},
#    {'value': 'Padmé Amidala'},
#    {'value': 'Obi-Wan'},
#    {'value': 'Zam Wesell'},
#    {'value': 'Polis Massa'},
#    {'value': 'K-2SO'},
#    {'value': 'Cassian Andor'},
#    {'value': 'Ben'},
#    {'value': 'Senator Palpatine'},
#    {'value': 'Poe Dameron'},
#    {'value': 'Chancellor Valorum'},
#    {'value': 'Anakin'},
#    {'value': 'Hux'},
#    {'value': 'Qui-Gon'},
#    {'value': 'Queen Amidala'},
#    {'value': 'General Leia Organa'},
#    {'value': 'Count Dooku'},
#    {'value': 'Viceroy Nute Gunray'},
#    {'value': 'General Draven'},
#    {'value': 'Obi-Wan Kenobi'},
#    {'value': 'Han'},
#    {'value': 'Finn'},
#    {'value': 'Luke Skywalker'},
#    {'value': 'Dagobah'},
#    {'value': 'Mace Windu'},
#    {'value': 'Emperor Palpatine'},
#    {'value': 'Boba'},
#    {'value': 'Orson Krennic'},
#    {'value': 'Organa'},
#    {'value': 'Maz Kanata'},
#    {'value': 'Jyn'},
#    {'value': 'Princess Leia'},
#    {'value': 'Boba Fett'},
#    {'value': 'Supreme Chancellor Palpatine'},
#    {'value': 'Jango Fett'}]},
#  {'entity': 'Organization',
#   'values': [{'value': 'droid army'},
#    {'value': 'Confederacy of Independent Systems'},
#    {'value': 'Tusken Raiders'},
#    {'value': 'Senate'},
#    {'value': 'Federation'},
#    {'value': 'Alliance Council'},
#    {'value': 'Galactic Republic'},
#    {'value': 'Galactic Senate'},
#    {'value': 'Trade Federation'},
#    {'value': 'Jedi Council'},
#    {'value': 'Rebel assault squadron'},
#    {'value': 'Rebel Alliance'},
#    {'value': 'Falcon'},
#    {'value': 'Force'}]},
#  {'entity': 'Location',
#   'values': [{'value': 'San Tekka'},
#    {'value': 'Wobani'},
#    {'value': 'New Republic'},
#    {'value': 'Gungans'},
#    {'value': 'Naboo'},
#    {'value': 'Tusken'},
#    {'value': 'Geonosis'},
#    {'value': 'Scarif'},
#    {'value': 'Sarlacc'},
#    {'value': 'BB-8'},
#    {'value': 'Podrace'},
#    {'value': 'Tatooine'},
#    {'value': 'Takodana'},
#    {'value': 'Valorum'},
#    {'value': 'Jedha'},
#    {'value': 'Mustafar'},
#    {'value': 'Theed'},
#    {'value': 'Jakku'},
#    {'value': 'Cassian'},
#    {'value': 'Padmé'},
#    {'value': 'Gerrera'},
#    {'value': 'Alderaan'},
#    {'value': 'Kashyyyk'},
#    {'value': 'Dagobah'},
#    {'value': 'Coruscant'}]}]

# %% [markdown]
# Update the workspace with these entities and verify that have been added correctly.

# %%
# Add these grouped entities to the Conversation workspace
conversation.update_workspace(workspace_id=wrk_id, entities=entities_grouped)

workspace_details = conversation.get_workspace(workspace_id=wrk_id, export=True)
print(json.dumps(workspace_details["entities"], indent=2))
# Out:
# [
#   {
#     "updated": "2018-08-07T22:23:59.664Z",
#     "created": "2018-08-07T22:23:59.664Z",
#     "values": [
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Cassian Andor",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Ben",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Senator Palpatine",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Poe Dameron",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Chancellor Valorum",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Anakin",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Hux",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Qui-Gon",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Orson Krennic",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Boba",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Emperor Palpatine",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Mace Windu",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Dagobah",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Luke Skywalker",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Finn",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Jango Fett",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Han",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Supreme Chancellor Palpatine",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Boba Fett",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Princess Leia",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Jyn",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Maz Kanata",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Organa",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Obi-Wan Kenobi",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "General Draven",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Viceroy Nute Gunray",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Count Dooku",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "General Leia Organa",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Queen Amidala",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Cliegg Lars",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Lyra",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Bodhi Rook",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Baze Malbus",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Tarkin",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Anakin Skywalker",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Watto",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Lando Calrissian",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Owen",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Darth Vader",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Mon Mothma",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Wookiee",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Darth Maul",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Gunray",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Shmi",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Darth Sidious",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Senator Padm\u00e9 Amidala",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Han Solo",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Cassian",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Luke",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Boss Nass",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Kylo Ren",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Galen Erso",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Rey",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Leia",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Chirrut \u00cemwe",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Padm\u00e9",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Beru Lars",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Yoda",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Padm\u00e9 Amidala",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Obi-Wan",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Zam Wesell",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Polis Massa",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "K-2SO",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       }
#     ],
#     "entity": "Person",
#     "open_list": null,
#     "type": null,
#     "description": null,
#     "source": null
#   },
#   {
#     "updated": "2018-08-07T22:23:59.664Z",
#     "created": "2018-08-07T22:23:59.664Z",
#     "values": [
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Falcon",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Cloud City",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "carbonite",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Mos Espa",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Imperial communications",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Federation Viceroy Nute Gunray",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Jawa traders",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "General Hux",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       }
#     ],
#     "entity": "Company",
#     "open_list": null,
#     "type": null,
#     "description": null,
#     "source": null
#   },
#   {
#     "updated": "2018-08-07T22:23:59.664Z",
#     "created": "2018-08-07T22:23:59.664Z",
#     "values": [
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "assault",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       }
#     ],
#     "entity": "Crime",
#     "open_list": null,
#     "type": null,
#     "description": null,
#     "source": null
#   },
#   {
#     "updated": "2018-08-07T22:23:59.664Z",
#     "created": "2018-08-07T22:23:59.664Z",
#     "values": [
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Tusken",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Naboo",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Gungans",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "New Republic",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Wobani",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "San Tekka",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Coruscant",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Dagobah",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Kashyyyk",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Alderaan",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Gerrera",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Padm\u00e9",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Cassian",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Jakku",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Theed",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Mustafar",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Jedha",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Valorum",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Takodana",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Tatooine",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Podrace",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "BB-8",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Sarlacc",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Geonosis",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Scarif",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       }
#     ],
#     "entity": "Location",
#     "open_list": null,
#     "type": null,
#     "description": null,
#     "source": null
#   },
#   {
#     "updated": "2018-08-07T22:23:59.664Z",
#     "created": "2018-08-07T22:23:59.664Z",
#     "values": [
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "engineer",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "developer",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Research scientist",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "officer",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "representative",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "chancellor",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "commander",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       }
#     ],
#     "entity": "JobTitle",
#     "open_list": null,
#     "type": null,
#     "description": null,
#     "source": null
#   },
#   {
#     "updated": "2018-08-07T22:23:59.664Z",
#     "created": "2018-08-07T22:23:59.664Z",
#     "values": [
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Sarlacc pit",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Starkiller Base",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       }
#     ],
#     "entity": "GeographicFeature",
#     "open_list": null,
#     "type": null,
#     "description": null,
#     "source": null
#   },
#   {
#     "updated": "2018-08-07T22:23:59.664Z",
#     "created": "2018-08-07T22:23:59.664Z",
#     "values": [
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Rebel Alliance",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Rebel assault squadron",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Jedi Council",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Trade Federation",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Galactic Senate",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Galactic Republic",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Alliance Council",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Federation",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Senate",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Tusken Raiders",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Confederacy of Independent Systems",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "droid army",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Falcon",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Force",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       }
#     ],
#     "entity": "Organization",
#     "open_list": null,
#     "type": null,
#     "description": null,
#     "source": null
#   },
#   {
#     "updated": "2018-08-07T22:23:59.664Z",
#     "created": "2018-08-07T22:23:59.664Z",
#     "values": [
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Imperial shuttle",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Jabba's palace",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Jedi Temple",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Galactic Empire",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Grand Moff Tarkin",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       }
#     ],
#     "entity": "Facility",
#     "open_list": null,
#     "type": null,
#     "description": null,
#     "source": null
#   },
#   {
#     "updated": "2018-08-07T22:23:59.664Z",
#     "created": "2018-08-07T22:23:59.664Z",
#     "values": [
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Fifteen years",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Three decades",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Three years",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "one",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "Ten years",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       },
#       {
#         "updated": "2018-08-07T22:23:59.664Z",
#         "value": "nine-year",
#         "created": "2018-08-07T22:23:59.664Z",
#         "metadata": null,
#         "type": "synonyms",
#         "synonyms": []
#       }
#     ],
#     "entity": "Quantity",
#     "open_list": null,
#     "type": null,
#     "description": null,
#     "source": null
#   }
# ]

# %% [markdown]
# _**Note**: Ensure that at least 3 entity types, with at least 1 example entity each have been added._
#
# Here is what the list of entities should look like through the Conversation tool.
#
# <img src="images/conversation-entities.png" alt="Conversation service - Entities listed" width="800" />
#
# **Q**: Name 3 entity types that were added, with at least 1 example entity each (e.g. entity type: _City_, example: _Los Angeles_).
#
# **A**: No.

# %% [markdown]
# ### Design dialog flow
#
# As a final step in creating the Conversation interface, let's design a typical dialog with a user. The most intuitive way to do this is to use the Dialog tab in the tool. Here, you can add _nodes_ that capture different stages in the dialog flow, and connect them in a meaningful way.
#
# Go ahead and add at least 3 dialog nodes. Specify the triggers in terms of the intents and entities that you'd like to match, and an optional intermediate response like "Let me find that out for you." The actual response will be fetched by querying the Discovery service.
#
# Here is what the dialog nodes should look like.
#
# <img src="images/conversation-dialog_nodes.png" alt="Conversation service - Dialog nodes" width="640" />
#
# **Q**: Specify 3 dialog nodes you added, along with the trigger (intent and/or entities) for each.
#
# **A**:

# %% [markdown]
# ### Test dialog
#
# Let's run through a test dialog to demonstrate how the system transitions to one of the nodes you defined above.

# %%
# Testing the dialog flow

# Start conversation with a blank message
results = conversation.message(workspace_id=wrk_id, message_input={})
context = results["context"]

# Then ask a sample question
question= "Who is Luke's father?"
results = conversation.message(workspace_id=wrk_id, message_input={
    "text": question,
    "context": context
})
print(json.dumps(results, indent=2))
# Out:
# {
#   "entities": [],
#   "input": {},
#   "intents": [],
#   "context": {
#     "conversation_id": "0c51a5d7-8601-4851-9e31-925e47485a0b",
#     "system": {
#       "branch_exited_reason": "completed",
#       "_node_output_map": {
#         "Welcome": {
#           "0": [
#             0
#           ]
#         }
#       },
#       "branch_exited": true,
#       "dialog_stack": [
#         {
#           "dialog_node": "root"
#         }
#       ],
#       "dialog_turn_counter": 1,
#       "dialog_request_counter": 1
#     }
#   },
#   "output": {
#     "text": [
#       "Hello. How can I help you?"
#     ],
#     "nodes_visited": [
#       "Welcome"
#     ],
#     "log_messages": []
#   }
# }

# %% [markdown]
# ## 4. Query document collection to fetch answers
#
# The Discovery service includes a simple mechanism to make queries against your enriched collection of documents. But you have a lot of control over what fields are searched, how results are aggregated and values are returned.
#
# ### Process sample question
#
# Choose a sample nautal language question to ask, and run it through the Conversation service, just like you did above when testing dialog flow.

# %%
# TODO: Run a sample question through Conversation service
results = conversation.message(workspace_id=wrk_id, message_input={})
context = results["context"]
question= "What does Luke pilot?"
results = conversation.message(workspace_id=wrk_id, message_input={
    "text": question,
    "context": context
})
print(json.dumps(results, indent=2))
# Out:
# {
#   "entities": [],
#   "input": {},
#   "intents": [],
#   "context": {
#     "conversation_id": "b7228f05-11bc-4a70-bbf1-31a48e78be03",
#     "system": {
#       "branch_exited_reason": "completed",
#       "_node_output_map": {
#         "Welcome": {
#           "0": [
#             0
#           ]
#         }
#       },
#       "branch_exited": true,
#       "dialog_stack": [
#         {
#           "dialog_node": "root"
#         }
#       ],
#       "dialog_turn_counter": 1,
#       "dialog_request_counter": 1
#     }
#   },
#   "output": {
#     "text": [
#       "Hello. How can I help you?"
#     ],
#     "nodes_visited": [
#       "Welcome"
#     ],
#     "log_messages": []
#   }
# }

# %% [markdown]
# Now extract the intent and entities identified in the question, and optionally what dialog node was triggered (in case you need it later to customize your response). Some sample code is provided below, but you may need to modify it.

# %%
# TODO: Identify the intent(s) the user expressed (typically a single one)
query_intents = [intent["intent"] for intent in results["intents"]]
print("Intent(s):", query_intents)

# TODO: Extract the entities found in the question text
query_entities = [entity["value"] for entity in results["entities"]]
print("Entities:", query_entities)

# TODO: (optional) Find out what dialog node was triggered
# Out:
# Intent(s): []
# Entities: []

# %% [markdown]
# ### Query the collection
#
# Design a query based on the information extracted above, and run it against the document collection. The sample query provided below simple looks for all the entities in the raw `text` field. Modify it to suit your needs.
#
# Take a look at the [API Reference](https://www.ibm.com/watson/developercloud/discovery/api/v1/?python#query-collection) to learn more about the query options available, and for more guidance see this [documentation page](https://www.ibm.com/watson/developercloud/doc/discovery/using.html).
#
# _**Note**: You may want to design different queries based on the intent / dialog node that was triggered._

# %%
# TODO: Query the Discovery service based on the intent and entities
query_results = discovery.query(environment_id=env_id, collection_id=col_id,
    query_options={
        "query": "text:{}".format(",".join("\"{}\"".format(e) for e in query_entities)),
        "return": "text"
    })
print(json.dumps(query_results, indent=2))

# %% [markdown]
# ### Process returned results
#
# If you properly structure the query, Watson is able to do a pretty good job of finding the relevant information. But the result returned is a JSON object. Now your task is to convert that result into an appropriate response that best addresses the original natural language question that was asked.
#
# E.g. if the question was "Who saved Han Solo from Jabba the Hutt?" the answer should ideally just be "The Rebels" and not the entire paragraph describing Han Solo's rescue. But that can be a backup response if you cannot be more specific.
#
# _**Note**: You may have to go back to the previous step and modify the query, especially what you want the Discovery service to return, and this may depend on the intent / dialog node triggered. E.g. study the different parts of a "relation" structure to see how you might construct queries to match them._

# %%
# TODO: Process returned results and compose an appropriate response

# %% [markdown]
# ## 5. Reflections
#
# **Q**: Now that you have gone through this exercise of designing a system that uses two IBM Watson services, what did you learn? What were some of the strengths and weaknesses of this approach?
#
# **A**:
#
#
# ## (Optional) Extensions
#
# We have provided a set of sample data files containing Star Wars plot summaries. But as mentioned before, you are free to use your own dataset. In fact, a larger dataset maybe more suitable for use with IBM Watson's NLP services. If you used your own dataset, answer the following questions.
#
# **Q**: What dataset did you use, and in what ways is it different from the sample files provided?
#
# **A**:
#
#
# **Q**: Either include your dataset in the .zip file or repository you submit, or provide clear instructions on how to obtain the dataset, so that your reviewer can run your notebook or inspect the data to verify your results.
#
# **A**:
#
#
# _You can also design a web-based application that utilizes these services and deploy that on Bluemix! If you do, please share with your instructors and peers._
